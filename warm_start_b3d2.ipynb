# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeDongHun38/recommendation_LLM/blob/main/warm_start_b3d2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Warm Start 추천용 NeuMF 모델 제작**
#
# 🎯 **단계 목표**
#
# * NeuMF의 핵심인 GMF(선형) 경로와 MLP(비선형) 경로를 모두 갖춘 하이브리드 모델을 정의한다.
#
# * 최종적으로 만든 mapped_ablation_df.pkl 데이터셋을 사용하여 모델을 훈련시킨다.
#
# * 훈련된 모델의 성능을 평점 예측 정확도(RMSE, MAE)와 추천 순위 정확도(Precision, Recall, NDCG) 두 가지 관점에서 종합적으로 평가한다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
from collections import defaultdict
from tqdm.auto import tqdm

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"    - 사용 디바이스: {device}")
# Out:
#     - 사용 디바이스: cuda

# %% [markdown]
# # **0. 데이터 분할**

# %% [markdown]
# 모든 column에 대한 임베딩 + mapped 까지 완료된 [mapped_ablation_df.pkl 사용]해 warm start 추천을 진행할 예정이다 (이거 잘 모르겠음 dataPreprocessing_b3d2 참고하면됨)

# %% [markdown]
# **왜 mapped 된 데이터가 필요한가?**
#
# ID를 숫자로 매핑하는 이유는, 복잡한 문자열로 된 현실 세계의 개체(사용자, 영화)를, NeuMF 모델의 nn.Embedding 레이어가 직접 조회하고 처리할 수 있게 효율적인 '주소(정수 인덱스)'로 변환해 주기 위함이다.
#
# 1. GMF (Generalized Matrix Factorization) 경로
# * 코드: self.user_embedding_gmf = nn.Embedding(num_users, gmf_dim)
# * 역할: 이 코드는 GMF 경로 전용 '사용자 사물함 공간'을 만든다.
# * 동작 방식: 모델이 user_id_mapped = 215라는 값을 받으면, 이 GMF용 사용자 사물함 공간의 215번째 사물함을 열어 그 안에 있는 개인 물품(GMF용 임베딩 벡터)을 꺼낸다. 아이템에 대해서도 동일한 작업을 수행한 후, 두 벡터를 결합하여 1차적인 취향을 분석.
#
# 2. MLP (Multi-Layer Perceptron) 경로
# * 코드: self.user_embedding_mlp = nn.Embedding(num_users, mlp_dim)
# * 역할: 이번에는 MLP 경로 전용 '사용자 사물함 공간'을 별도로 만든다. (GMF와 MLP는 서로 다른 관점에서 취향을 학습하기 위해 별도의 사물함을 사용.)
# * 동작 방식: 마찬가지로 user_id_mapped = 215가 입력되면, MLP용 사물함 공간의 215번째 사물함에서 벡터를 꺼낸다. 그리고 director_id_mapped, cast_id_mapped 등 다른 모든 Feature들도 각자의 사물함 공간에서 해당 번호의 벡터를 꺼내와 한데 모아 복잡한 취향을 분석
#
# **-> 결론: 딥러닝 layer의 nn.Embedding을 사용하기 위해서는, 정수 인덱스가 필요하고, 그렇기 때문에 mapping 하는 과정이 필수적이다.**

# %%
# 데이터 로드
try:
    input_dir = '/content/drive/MyDrive/데사경영학술제/data/'
    df = pd.read_pickle(input_dir + 'mapped_ablation_df.pkl')

    print("데이터 로드 완료")
    print(f"데이터 크기: {df.shape}")
    print(f"사용자 수: {df['user_id_mapped'].nunique()}")
    print(f"아이템 수: {df['asin_mapped'].nunique()}")
    print(f"컬럼 목록: {list(df.columns)}")
except Exception as e:
    print(f"데이터 로드 실패: {e}")
# Out:
# 데이터 로드 완료
# 데이터 크기: (26394, 25)
# 사용자 수: 1972
# 아이템 수: 6613
# 컬럼 목록: ['user_id', 'asin', 'user_id_mapped', 'asin_mapped', 'rating', 'average_rating', 'norm_average_rating', 'title', 'emb_title', 'description', 'emb_description', 'Directors', 'emb_directors', 'Producers', 'emb_producers', 'Cast', 'emb_cast', 'norm_year', 'Runtime_min', 'norm_runtime', 'represent_review', 'sim_review', 'Directors_mapped', 'Producers_mapped', 'Cast_mapped']

# %%
df.head()
# Out:
#                         user_id        asin  user_id_mapped  asin_mapped  \
# 0  AFZUK3MTBIBEDQOPAK3OATUOUKLA  B0B6NHYWP9               0            0
# 1  AFZUK3MTBIBEDQOPAK3OATUOUKLA  B0B5W6R5KW               0            1
# 2  AFZUK3MTBIBEDQOPAK3OATUOUKLA  B015SKC7KW               0            2
# 3  AFZUK3MTBIBEDQOPAK3OATUOUKLA  B00901SNW2               0            3
# 4  AFZUK3MTBIBEDQOPAK3OATUOUKLA  B00BHU9CCO               0            4
#
#    rating  average_rating  norm_average_rating              title  \
# 0     3.0             4.1             0.735294              Beast
# 1     3.0             3.9             0.676471  The Reef: Stalked
# 2     5.0             4.8             0.941176         The Intern
# 3     5.0             4.7             0.911765         Funny Farm
# 4     5.0             4.8             0.941176     Monsters, Inc.
#
#                                            emb_title  \
# 0  [-0.10075759887695312, 0.048774100840091705, -...
# 1  [0.044670939445495605, 0.04177572578191757, -0...
# 2  [-0.05135945975780487, 0.06857355684041977, 0....
# 3  [-0.04794826731085777, 0.016836734488606453, -...
# 4  [-0.08539490401744843, -0.027209490537643433, ...
#
#                                          description  ...  \
# 0  ['Idris Elba stars in a thriller about a fathe...  ...
# 1  ['While on a kayaking and diving trip, three f...  ...
# 2  ['In “The Intern,” Ben Whittaker (Robert De Ni...  ...
# 3  ["Life in the country isn't what it's cracked ...  ...
# 4  ['Monsters working at a scream processing fact...  ...
#
#                                                 Cast  \
# 0        Liyabuya Gongo, Martin Munro, Daniel Hadebe
# 1                                            Unknown
# 2  Robert De Niro, Anne Hathaway, Rene Russo, And...
# 3  Chevy Chase, Madolyn Smith, Joseph Maher, Jack...
# 4  John Goodman, Billy Crystal, Mary Gibbs, Steve...
#
#                                             emb_cast norm_year Runtime_min  \
# 0  [-0.05685826390981674, 0.009362559765577316, -...  0.971154          92
# 1  [-0.04310256615281105, 0.06563699245452881, -0...  0.894231          88
# 2  [-0.11262031644582748, -0.0218304805457592, -0...  0.903846         121
# 3  [-0.10283691436052322, -0.039987754076719284, ...  0.644231         101
# 4  [-0.04850676655769348, -0.05023813992738724, -...  0.769231          92
#
#   norm_runtime                                   represent_review  \
# 0     0.190377  [-0.037671849317848685, -0.008460467355325818,...
# 1     0.182008  [-0.10207390785217285, 0.012077383697032928, 0...
# 2     0.251046  [-0.0640731165301986, -0.003375221008900553, -...
# 3     0.209205  [-0.0424071795506669, -0.022781802607434138, -...
# 4     0.190377  [-0.05103557869895465, 0.01312201532224814, -0...
#
#                                           sim_review  Directors_mapped  \
# 0  The movie was OK and entertaining. Their was o...                 0
# 1  movie reviews - so subjective... so here goes....                 1
# 2  Rather an oldie - but a cute, satisfying story...                 2
# 3  Great Chevy Chase classic.  I have a postman t...                 3
# 4                                 Great family film.                 4
#
#    Producers_mapped  Cast_mapped
# 0                 0            0
# 1                 1            1
# 2                 2            2
# 3                 3            3
# 4                 4            4
#
# [5 rows x 25 columns]

# %%
# **강력한 임베딩 정규화 함수**
def force_normalize_embeddings(df):
    """
    모든 임베딩을 강제로 float32 numpy 배열로 변환
    """
    print("=== 강력한 임베딩 정규화 시작 ===")

    # emb_description 강제 정규화
    print("Description 임베딩 정규화 중...")
    normalized_desc = []
    for i, emb in enumerate(tqdm(df['emb_description'])):
        try:
            if isinstance(emb, np.ndarray):
                if emb.dtype == np.object_:
                    # object 타입이면 tolist() 후 다시 배열화
                    emb_list = emb.tolist()
                    if isinstance(emb_list, list) and len(emb_list) > 0:
                        normalized_desc.append(np.array(emb_list, dtype=np.float32))
                    else:
                        normalized_desc.append(np.zeros(384, dtype=np.float32))
                else:
                    normalized_desc.append(emb.astype(np.float32))
            elif isinstance(emb, list):
                normalized_desc.append(np.array(emb, dtype=np.float32))
            else:
                normalized_desc.append(np.zeros(384, dtype=np.float32))
        except Exception as e:
            print(f"Description 임베딩 {i} 처리 오류: {e}")
            normalized_desc.append(np.zeros(384, dtype=np.float32))

    # emb_title 강제 정규화
    print("Title 임베딩 정규화 중...")
    normalized_title = []
    for i, emb in enumerate(tqdm(df['emb_title'])):
        try:
            if isinstance(emb, np.ndarray):
                if emb.dtype == np.object_:
                    # object 타입이면 tolist() 후 다시 배열화
                    emb_list = emb.tolist()
                    if isinstance(emb_list, list) and len(emb_list) > 0:
                        normalized_title.append(np.array(emb_list, dtype=np.float32))
                    else:
                        normalized_title.append(np.zeros(384, dtype=np.float32))
                else:
                    normalized_title.append(emb.astype(np.float32))
            elif isinstance(emb, list):
                normalized_title.append(np.array(emb, dtype=np.float32))
            else:
                normalized_title.append(np.zeros(384, dtype=np.float32))
        except Exception as e:
            print(f"Title 임베딩 {i} 처리 오류: {e}")
            normalized_title.append(np.zeros(384, dtype=np.float32))

    # DataFrame에 다시 할당
    df['emb_description'] = normalized_desc
    df['emb_title'] = normalized_title

    print("=== 강력한 임베딩 정규화 완료 ===")
    print(f"Description 임베딩 타입: {type(df['emb_description'].iloc[0])}, dtype: {df['emb_description'].iloc[0].dtype}")
    print(f"Title 임베딩 타입: {type(df['emb_title'].iloc[0])}, dtype: {df['emb_title'].iloc[0].dtype}")

    return df

# 강력한 임베딩 정규화 적용
df = force_normalize_embeddings(df)
# Out:
# === 강력한 임베딩 정규화 시작 ===
# Description 임베딩 정규화 중...
#   0%|          | 0/26394 [00:00<?, ?it/s]
# Title 임베딩 정규화 중...
#   0%|          | 0/26394 [00:00<?, ?it/s]
# === 강력한 임베딩 정규화 완료 ===
# Description 임베딩 타입: <class 'numpy.ndarray'>, dtype: float32
# Title 임베딩 타입: <class 'numpy.ndarray'>, dtype: float32

# %%
# **완전한 데이터 타입 검증 및 수정**

def check_and_fix_all_data_types(df):
    """
    DataFrame의 모든 컬럼에서 object 타입 문제 해결
    """
    print("=== 전체 데이터 타입 검증 및 수정 ===")

    # 수치형 컬럼들 강제 변환
    numeric_columns = ['norm_runtime', 'norm_year', 'norm_average_rating', 'Runtime_min', 'year', 'average_rating']

    for col in numeric_columns:
        if col in df.columns:
            print(f"  {col}: {df[col].dtype}")
            if df[col].dtype == 'object':
                print(f"    -> {col}에서 object 타입 발견! 수정 중...")
                # object 타입을 강제로 float로 변환
                df[col] = pd.to_numeric(df[col], errors='coerce').astype(np.float32)
                print(f"    -> {col} 수정 완료: {df[col].dtype}")
            else:
                # 이미 수치형이지만 float32로 통일
                df[col] = df[col].astype(np.float32)

    # 범주형 컬럼들 검증
    categorical_columns = ['Directors_mapped', 'Producers_mapped', 'Cast_mapped', 'user_id_mapped', 'asin_mapped']

    for col in categorical_columns:
        if col in df.columns:
            print(f"  {col}: {df[col].dtype}")
            if df[col].dtype == 'object':
                print(f"    -> {col}에서 object 타입 발견! 수정 중...")
                df[col] = df[col].astype('int64')
                print(f"    -> {col} 수정 완료: {df[col].dtype}")

    return df

# 전체 데이터 타입 수정
df = check_and_fix_all_data_types(df)
# Out:
# === 전체 데이터 타입 검증 및 수정 ===
#   norm_runtime: float64
#   norm_year: float64
#   norm_average_rating: float64
#   Runtime_min: int64
#   average_rating: float64
#   Directors_mapped: int64
#   Producers_mapped: int64
#   Cast_mapped: int64
#   user_id_mapped: int64
#   asin_mapped: int64

# %%
# 데이터 분할

def improved_split_user_interactions(df, val_ratio=0.2, min_interactions=5, seed=42):
    """
    최소 상호작용 수를 보장하는 개선된 데이터 분할 함수
    """
    print(f"개선된 데이터 분할 시작 (최소 상호작용: {min_interactions}개)")

    # 최소 상호작용 수를 만족하는 사용자만 필터링
    user_counts = df.groupby('user_id_mapped').size()
    valid_users = user_counts[user_counts >= min_interactions].index
    df_filtered = df[df['user_id_mapped'].isin(valid_users)]

    print(f"원본 사용자 수: {df['user_id_mapped'].nunique()}")
    print(f"필터링 후 사용자 수: {df_filtered['user_id_mapped'].nunique()}")
    print(f"원본 상호작용 수: {len(df)}")
    print(f"필터링 후 상호작용 수: {len(df_filtered)}")

    train_rows, val_rows = [], []

    for user_id, user_group in df_filtered.groupby('user_id_mapped'):
        if len(user_group) < 2:
            train_rows.append(user_group)
            continue

        try:
            train_grp, val_grp = train_test_split(
                user_group,
                test_size=val_ratio,
                random_state=seed,
                stratify=user_group['rating'].round(1)
            )
        except ValueError:
            train_grp, val_grp = train_test_split(
                user_group,
                test_size=val_ratio,
                random_state=seed
            )

        train_rows.append(train_grp)
        val_rows.append(val_grp)

    train_df_new = pd.concat(train_rows, ignore_index=True)
    val_df_new = pd.concat(val_rows, ignore_index=True)

    print(f"훈련 세트 크기: {len(train_df_new)}")
    print(f"검증 세트 크기: {len(val_df_new)}")

    return train_df_new, val_df_new

# %%
# 개선된 분할 적용
train_df, val_df = improved_split_user_interactions(df, val_ratio=0.2, min_interactions=5)

# 사용자별 상호작용 딕셔너리 생성
user_item_train = train_df.groupby('user_id_mapped')['asin_mapped'].apply(set).to_dict()
val_df_positive = val_df[val_df['rating'] >= 4.0]
user_item_val = val_df_positive.groupby('user_id_mapped')['asin_mapped'].apply(set).to_dict()

# **아이템 마스터 테이블 생성 및 임베딩 재정규화**
print("=== 아이템 마스터 테이블 임베딩 재정규화 ===")

all_items_df = df.drop_duplicates(subset=['asin_mapped']).set_index('asin_mapped')

# all_items_df의 임베딩도 강제로 재정규화
print("아이템 마스터 테이블 임베딩 정규화 중...")

# Description 임베딩 재정규화
normalized_desc_items = []
for i, emb in enumerate(tqdm(all_items_df['emb_description'], desc="Items Description 정규화")):
    try:
        if isinstance(emb, np.ndarray):
            if emb.dtype == np.object_:
                emb_list = emb.tolist()
                if isinstance(emb_list, list) and len(emb_list) > 0:
                    normalized_desc_items.append(np.array(emb_list, dtype=np.float32))
                else:
                    normalized_desc_items.append(np.zeros(384, dtype=np.float32))
            else:
                normalized_desc_items.append(emb.astype(np.float32))
        elif isinstance(emb, list):
            normalized_desc_items.append(np.array(emb, dtype=np.float32))
        else:
            normalized_desc_items.append(np.zeros(384, dtype=np.float32))
    except Exception as e:
        normalized_desc_items.append(np.zeros(384, dtype=np.float32))

# Title 임베딩 재정규화
normalized_title_items = []
for i, emb in enumerate(tqdm(all_items_df['emb_title'], desc="Items Title 정규화")):
    try:
        if isinstance(emb, np.ndarray):
            if emb.dtype == np.object_:
                emb_list = emb.tolist()
                if isinstance(emb_list, list) and len(emb_list) > 0:
                    normalized_title_items.append(np.array(emb_list, dtype=np.float32))
                else:
                    normalized_title_items.append(np.zeros(384, dtype=np.float32))
            else:
                normalized_title_items.append(emb.astype(np.float32))
        elif isinstance(emb, list):
            normalized_title_items.append(np.array(emb, dtype=np.float32))
        else:
            normalized_title_items.append(np.zeros(384, dtype=np.float32))
    except Exception as e:
        normalized_title_items.append(np.zeros(384, dtype=np.float32))

# all_items_df에 정규화된 임베딩 할당
all_items_df['emb_description'] = normalized_desc_items
all_items_df['emb_title'] = normalized_title_items

# all_items_df도 데이터 타입 수정
all_items_df = check_and_fix_all_data_types(all_items_df)

all_item_ids_mapped = all_items_df.index.values

print("데이터 분할 및 딕셔너리 생성 완료")
# Out:
# 개선된 데이터 분할 시작 (최소 상호작용: 5개)
# 원본 사용자 수: 1972
# 필터링 후 사용자 수: 1932
# 원본 상호작용 수: 26394
# 필터링 후 상호작용 수: 26274
# 훈련 세트 크기: 20282
# 검증 세트 크기: 5992
# === 아이템 마스터 테이블 임베딩 재정규화 ===
# 아이템 마스터 테이블 임베딩 정규화 중...
# Items Description 정규화:   0%|          | 0/6613 [00:00<?, ?it/s]
# Items Title 정규화:   0%|          | 0/6613 [00:00<?, ?it/s]
# === 전체 데이터 타입 검증 및 수정 ===
#   norm_runtime: float32
#   norm_year: float32
#   norm_average_rating: float32
#   Runtime_min: float32
#   average_rating: float32
#   Directors_mapped: int64
#   Producers_mapped: int64
#   Cast_mapped: int64
#   user_id_mapped: int64
# 데이터 분할 및 딕셔너리 생성 완료

# %%
# 안전한 임베딩 스택 함수

def ultra_safe_embedding_stack(embedding_series, target_dim=384):
    """
    완전히 안전한 임베딩 스택 함수
    """
    embeddings = []
    for emb in embedding_series:
        try:
            if isinstance(emb, np.ndarray) and emb.dtype != np.object_ and emb.shape[0] == target_dim:
                embeddings.append(emb.astype(np.float32))
            elif isinstance(emb, list) and len(emb) == target_dim:
                embeddings.append(np.array(emb, dtype=np.float32))
            else:
                embeddings.append(np.zeros(target_dim, dtype=np.float32))
        except:
            embeddings.append(np.zeros(target_dim, dtype=np.float32))

    return np.stack(embeddings)

# %%
# 안전한 텐서 변환 함수

def hyper_safe_tensor_conversion(data, target_shape=384, target_dtype=torch.float32):
    """
    극도로 안전한 텐서 변환 함수 - 모든 경우의 수 고려
    """
    try:
        if data is None:
            return torch.zeros(target_shape, dtype=target_dtype).to(device)

        if isinstance(data, torch.Tensor):
            if len(data.shape) > 0 and data.shape[-1] == target_shape:
                return data.to(target_dtype).to(device)
            else:
                return torch.zeros(target_shape, dtype=target_dtype).to(device)

        elif isinstance(data, np.ndarray):
            if data.dtype == np.object_:
                try:
                    data_list = data.tolist()
                    if isinstance(data_list, list) and len(data_list) == target_shape:
                        return torch.tensor(data_list, dtype=target_dtype).to(device)
                    elif isinstance(data_list, list):
                        flat_list = np.array(data_list).flatten()
                        if len(flat_list) == target_shape:
                            return torch.tensor(flat_list, dtype=target_dtype).to(device)
                    elif hasattr(data, 'item'):
                        item_val = data.item()
                        if isinstance(item_val, (list, np.ndarray)) and len(item_val) == target_shape:
                            return torch.tensor(item_val, dtype=target_dtype).to(device)

                    return torch.zeros(target_shape, dtype=target_dtype).to(device)
                except:
                    return torch.zeros(target_shape, dtype=target_dtype).to(device)
            else:
                if len(data.shape) > 0 and data.shape[-1] == target_shape:
                    return torch.tensor(data, dtype=target_dtype).to(device)
                elif data.size == target_shape:
                    reshaped_data = data.reshape(target_shape)
                    return torch.tensor(reshaped_data, dtype=target_dtype).to(device)
                else:
                    return torch.zeros(target_shape, dtype=target_dtype).to(device)

        elif isinstance(data, list):
            if len(data) == target_shape:
                return torch.tensor(data, dtype=target_dtype).to(device)
            else:
                return torch.zeros(target_shape, dtype=target_dtype).to(device)

        else:
            try:
                scalar_array = np.full(target_shape, float(data), dtype=np.float32)
                return torch.tensor(scalar_array, dtype=target_dtype).to(device)
            except:
                return torch.zeros(target_shape, dtype=target_dtype).to(device)

    except Exception as e:
        print(f"극도 안전 텐서 변환 오류 (기본값 사용): {e}")
        return torch.zeros(target_shape, dtype=target_dtype).to(device)

# %%
# 안전한 Dataset 클래스

class UltraSafeHybridDataset(Dataset):
    def __init__(self, df):
        self.users = torch.LongTensor(df['user_id_mapped'].values)
        self.items = torch.LongTensor(df['asin_mapped'].values)
        self.directors = torch.LongTensor(df['Directors_mapped'].values)
        self.producers = torch.LongTensor(df['Producers_mapped'].values)
        self.cast = torch.LongTensor(df['Cast_mapped'].values)

        # 안전한 수치형 데이터 변환
        self.numericals = torch.FloatTensor(df[['norm_runtime', 'norm_year', 'norm_average_rating']].values)

        # **완전히 안전한 임베딩 변환**
        print("Dataset 완전 안전 임베딩 변환 중...")

        # 임베딩 차원 확인
        sample_desc = df['emb_description'].iloc[0]
        sample_title = df['emb_title'].iloc[0]

        if isinstance(sample_desc, np.ndarray):
            target_dim = sample_desc.shape[0] if sample_desc.shape[0] > 0 else 384
        else:
            target_dim = 384

        print(f"임베딩 차원: {target_dim}")

        desc_embeddings = ultra_safe_embedding_stack(df['emb_description'], target_dim)
        title_embeddings = ultra_safe_embedding_stack(df['emb_title'], target_dim)

        self.description_embeddings = torch.FloatTensor(desc_embeddings)
        self.title_embeddings = torch.FloatTensor(title_embeddings)

        self.ratings = torch.FloatTensor(df['rating'].values)
        print("Dataset 완전 안전 임베딩 변환 완료")

    def __len__(self):
        return len(self.users)

    def __getitem__(self, idx):
        return (self.users[idx], self.items[idx], self.directors[idx],
                self.producers[idx], self.cast[idx], self.numericals[idx],
                self.description_embeddings[idx], self.title_embeddings[idx],
                self.ratings[idx])

# %%
# 모델 정의 (Title + 평균별점 포함)

class EnhancedTrueHybridNeuMF(nn.Module):
    def __init__(self, num_users, num_items, num_directors, num_producers,
                 num_cast, text_embedding_dim, num_numerical_features,
                 gmf_dim=32, mlp_embedding_dim=32):
        super().__init__()

        self.user_embedding_gmf = nn.Embedding(num_users, gmf_dim)
        self.item_embedding_gmf = nn.Embedding(num_items, gmf_dim)

        self.user_embedding_mlp = nn.Embedding(num_users, mlp_embedding_dim)
        self.item_embedding_mlp = nn.Embedding(num_items, mlp_embedding_dim)
        self.director_embedding_mlp = nn.Embedding(num_directors, mlp_embedding_dim)
        self.producer_embedding_mlp = nn.Embedding(num_producers, mlp_embedding_dim)
        self.cast_embedding_mlp = nn.Embedding(num_cast, mlp_embedding_dim)

        self.description_embedding_projection = nn.Linear(text_embedding_dim, mlp_embedding_dim)
        self.title_embedding_projection = nn.Linear(text_embedding_dim, mlp_embedding_dim)

        mlp_input_dim = mlp_embedding_dim * 7 + num_numerical_features
        self.mlp_layers = nn.Sequential(
            nn.Linear(mlp_input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, 64)
        )

        self.prediction_layer = nn.Linear(gmf_dim + 64, 1)

    def forward(self, user_id, item_id, director_id, producer_id, cast_id,
                numerical_features, description_embedding, title_embedding):
        gmf_output = self.user_embedding_gmf(user_id) * self.item_embedding_gmf(item_id)

        mlp_input = torch.cat([
            self.user_embedding_mlp(user_id),
            self.item_embedding_mlp(item_id),
            self.director_embedding_mlp(director_id),
            self.producer_embedding_mlp(producer_id),
            self.cast_embedding_mlp(cast_id),
            self.description_embedding_projection(description_embedding),
            self.title_embedding_projection(title_embedding),
            numerical_features
        ], dim=1)

        mlp_output = self.mlp_layers(mlp_input)
        combined = torch.cat([gmf_output, mlp_output], dim=1)
        logits = self.prediction_layer(combined)

        return 1.0 + 4.0 * torch.sigmoid(logits).squeeze()

# Loss 정의
class RMSELoss(nn.Module):
    def __init__(self, eps=1e-6):
        super().__init__()
        self.mse = nn.MSELoss()
        self.eps = eps

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y) + self.eps)

# DataLoader 생성
train_loader = DataLoader(UltraSafeHybridDataset(train_df), batch_size=1024, shuffle=True)
val_loader = DataLoader(UltraSafeHybridDataset(val_df), batch_size=1024, shuffle=False)
# Out:
# Dataset 완전 안전 임베딩 변환 중...
# 임베딩 차원: 384
# Dataset 완전 안전 임베딩 변환 완료
# Dataset 완전 안전 임베딩 변환 중...
# 임베딩 차원: 384
# Dataset 완전 안전 임베딩 변환 완료

# %% [markdown]
# # **모델 훈련**

# %%
# 모델 파라미터 정의
num_users = df['user_id_mapped'].nunique()
num_items = df['asin_mapped'].nunique()
num_directors = df['Directors_mapped'].nunique()
num_producers = df['Producers_mapped'].nunique()
num_cast = df['Cast_mapped'].nunique()
text_embedding_dim = len(df['emb_description'].iloc[0])
num_numerical_features = 3

print(f"모델 파라미터:")
print(f"  - 사용자 수: {num_users}")
print(f"  - 아이템 수: {num_items}")
print(f"  - 텍스트 임베딩 차원: {text_embedding_dim}")
print(f"  - 수치형 특성 개수: {num_numerical_features}")
# Out:
# 모델 파라미터:
#   - 사용자 수: 1972
#   - 아이템 수: 6613
#   - 텍스트 임베딩 차원: 384
#   - 수치형 특성 개수: 3

# %%
# 모델, 손실함수, 옵티마이저 초기화
model = EnhancedTrueHybridNeuMF(
    num_users, num_items, num_directors, num_producers,
    num_cast, text_embedding_dim, num_numerical_features
).to(device)

criterion = RMSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.2, patience=3, verbose=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
# 훈련 함수
def train_epoch(model, loader, criterion, optimizer):
    model.train()
    total_loss = 0
    for u, i, d, p, c, num, desc_emb, title_emb, r in loader:
        u, i, d, p, c, num, desc_emb, title_emb, r = (t.to(device) for t in (u, i, d, p, c, num, desc_emb, title_emb, r))
        optimizer.zero_grad()
        prediction = model(u, i, d, p, c, num, desc_emb, title_emb)
        loss = criterion(prediction, r)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def validate_epoch(model, loader, criterion):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for u, i, d, p, c, num, desc_emb, title_emb, r in loader:
            u, i, d, p, c, num, desc_emb, title_emb, r = (t.to(device) for t in (u, i, d, p, c, num, desc_emb, title_emb, r))
            prediction = model(u, i, d, p, c, num, desc_emb, title_emb)
            total_loss += criterion(prediction, r).item()
    return total_loss / len(loader)

# %%
# 훈련 루프
num_epochs = 20
best_val_rmse = float('inf')

for epoch in range(num_epochs):
    train_rmse = train_epoch(model, train_loader, criterion, optimizer)
    val_rmse = validate_epoch(model, val_loader, criterion)

    print(f"Epoch {epoch+1:02d}, Train RMSE: {train_rmse:.4f}, Val RMSE: {val_rmse:.4f}")

    if val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        torch.save(model.state_dict(), 'best_final_neumf.pth')
        print("    -> Val RMSE 개선! 최고 성능 모델 저장.")

    scheduler.step(val_rmse)

print("\n--- 모델 훈련 종료 ---")
# Out:
# Epoch 01, Train RMSE: 1.3777, Val RMSE: 1.4008
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 02, Train RMSE: 1.3246, Val RMSE: 1.3358
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 03, Train RMSE: 1.2931, Val RMSE: 1.3156
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 04, Train RMSE: 1.2622, Val RMSE: 1.2977
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 05, Train RMSE: 1.2377, Val RMSE: 1.2950
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 06, Train RMSE: 1.2135, Val RMSE: 1.2809
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 07, Train RMSE: 1.1909, Val RMSE: 1.2740
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 08, Train RMSE: 1.1677, Val RMSE: 1.2670
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 09, Train RMSE: 1.1475, Val RMSE: 1.2671
# Epoch 10, Train RMSE: 1.1284, Val RMSE: 1.2677
# Epoch 11, Train RMSE: 1.1060, Val RMSE: 1.2594
#     -> Val RMSE 개선! 최고 성능 모델 저장.
# Epoch 12, Train RMSE: 1.0854, Val RMSE: 1.2668
# Epoch 13, Train RMSE: 1.0660, Val RMSE: 1.2687
# Epoch 14, Train RMSE: 1.0507, Val RMSE: 1.2729
# Epoch 15, Train RMSE: 1.0358, Val RMSE: 1.2697
# Epoch 16, Train RMSE: 0.9997, Val RMSE: 1.2687
# Epoch 17, Train RMSE: 1.0030, Val RMSE: 1.2701
# Epoch 18, Train RMSE: 0.9849, Val RMSE: 1.2694
# Epoch 19, Train RMSE: 0.9877, Val RMSE: 1.2703
# Epoch 20, Train RMSE: 0.9773, Val RMSE: 1.2696
#
# --- 모델 훈련 종료 ---

# %% [markdown]
# # **모델 평가 진행**

# %%
# 훈련된 모델 로드
try:
    model.load_state_dict(torch.load('best_final_neumf.pth'))
    model.eval()
    print("훈련된 모델 로드 완료")
except Exception as e:
    print(f"모델 로드 실패: {e}")
# Out:
# 훈련된 모델 로드 완료

# %%
# 평가 함수들
def comprehensive_rating_evaluation(model, val_loader, device):
    model.eval()
    all_predictions, all_actual_ratings = [], []
    with torch.no_grad():
        for u, i, d, p, c, num, desc_emb, title_emb, r in tqdm(val_loader, desc="Rating Prediction Evaluation"):
            u, i, d, p, c, num, desc_emb, title_emb, r = (t.to(device) for t in (u, i, d, p, c, num, desc_emb, title_emb, r))
            prediction = model(u, i, d, p, c, num, desc_emb, title_emb)
            all_predictions.extend(prediction.cpu().numpy())
            all_actual_ratings.extend(r.cpu().numpy())

    mae = mean_absolute_error(all_actual_ratings, all_predictions)
    rmse = math.sqrt(mean_squared_error(all_actual_ratings, all_predictions))
    return {'overall_mae': mae, 'overall_rmse': rmse}

def get_ranking_metrics(model, user_item_train, user_item_val, all_items_df, K, device):
    precisions, recalls, ndcgs = [], [], []
    user_iterator = tqdm(user_item_val.keys(), desc="Ranking Metrics Evaluation")

    for user_id in user_iterator:
        true_items = user_item_val[user_id]
        seen_items = user_item_train.get(user_id, set())
        candidate_items_df = all_items_df[~all_items_df.index.isin(seen_items)]
        if candidate_items_df.empty:
            continue

        cand_ids = candidate_items_df.index.values
        batch_size_eval = len(candidate_items_df)
        u_tensor = torch.LongTensor([user_id] * batch_size_eval).to(device)
        i_tensor = torch.LongTensor(cand_ids).to(device)
        d_tensor = torch.LongTensor(candidate_items_df['Directors_mapped'].values).to(device)
        p_tensor = torch.LongTensor(candidate_items_df['Producers_mapped'].values).to(device)
        c_tensor = torch.LongTensor(candidate_items_df['Cast_mapped'].values).to(device)

        num_tensor = torch.FloatTensor(candidate_items_df[['norm_runtime', 'norm_year', 'norm_average_rating']].values).to(device)
        desc_tensor = torch.FloatTensor(ultra_safe_embedding_stack(candidate_items_df['emb_description'], text_embedding_dim)).to(device)
        title_tensor = torch.FloatTensor(ultra_safe_embedding_stack(candidate_items_df['emb_title'], text_embedding_dim)).to(device)

        with torch.no_grad():
            predictions = model(u_tensor, i_tensor, d_tensor, p_tensor, c_tensor, num_tensor, desc_tensor, title_tensor)

        top_k_indices = torch.topk(predictions, k=min(K, len(predictions))).indices
        top_k_items = i_tensor[top_k_indices].cpu().numpy()

        hits = len(set(true_items) & set(top_k_items))
        precisions.append(hits / K)
        recalls.append(hits / len(true_items) if len(true_items) > 0 else 0)

        idcg = sum([1 / np.log2(i + 2) for i in range(len(true_items))])
        dcg = sum([1 / np.log2(i + 2) for i, item in enumerate(top_k_items) if item in true_items])
        ndcgs.append(dcg / idcg if idcg > 0 else 0)

    return np.mean(precisions), np.mean(recalls), np.mean(ndcgs)

# %%
# 평가 실행
rating_results = comprehensive_rating_evaluation(model, val_loader, device)
K = 10
precision, recall, ndcg = get_ranking_metrics(model, user_item_train, user_item_val, all_items_df, K, device)

print("\n" + "="*60)
print("          최종 완전한 가중치 기반 NeuMF 성능 리포트")
print("="*60)
print("\n[1. 평점 예측 정확도]")
print(f"  • 최종 RMSE: {rating_results['overall_rmse']:.4f}")
print(f"  • 최종 MAE : {rating_results['overall_mae']:.4f}")
print("\n[2. Top-10 추천 순위 정확도]")
print(f"  • Precision@10: {precision:.4f}")
print(f"  • Recall@10   : {recall:.4f}")
print(f"  • NDCG@10     : {ndcg:.4f}")
print("\n" + "="*60)
# Out:
# Rating Prediction Evaluation:   0%|          | 0/6 [00:00<?, ?it/s]
# Ranking Metrics Evaluation:   0%|          | 0/1752 [00:00<?, ?it/s]
# ============================================================
#           최종 완전한 가중치 기반 NeuMF 성능 리포트
# ============================================================
#
# [1. 평점 예측 정확도]
#   • 최종 RMSE: 1.2593
#   • 최종 MAE : 1.0170
#
# [2. Top-10 추천 순위 정확도]
#   • Precision@10: 0.0005
#   • Recall@10   : 0.0023
#   • NDCG@10     : 0.0010
#
# ============================================================

# %% [markdown]
# # **최종 가중치 기반 Feature Ablation**

# %%
# neutral_values 생성
def create_ultra_safe_neutral_values(df, device, text_embedding_dim):
    neutral_values = {}

    categorical_mappings = {
        'Directors_mapped': 'Directors',
        'Producers_mapped': 'Producers',
        'Cast_mapped': 'Cast'
    }

    for mapped_col, original_col in categorical_mappings.items():
        try:
            unknown_rows = df[df[original_col] == 'Unknown']
            if not unknown_rows.empty:
                neutral_values[mapped_col] = unknown_rows[mapped_col].iloc[0]
                print(f"{mapped_col} 중립값: {neutral_values[mapped_col]} (Unknown 사용)")
            else:
                most_common = df[original_col].value_counts().index[0]
                most_common_rows = df[df[original_col] == most_common]
                neutral_values[mapped_col] = most_common_rows[mapped_col].iloc[0]
                print(f"{mapped_col} 중립값: {neutral_values[mapped_col]} (최빈값 사용)")
        except Exception as e:
            neutral_values[mapped_col] = 0
            print(f"{mapped_col} 중립값: 0 (에러로 인한 기본값)")

    neutral_values['norm_runtime'] = df['norm_runtime'].mean()
    neutral_values['norm_year'] = df['norm_year'].mean()
    neutral_values['norm_average_rating'] = df['norm_average_rating'].mean()

    neutral_values['description_embedding'] = torch.zeros(text_embedding_dim, dtype=torch.float32).to(device)
    neutral_values['title_embedding'] = torch.zeros(text_embedding_dim, dtype=torch.float32).to(device)

    return neutral_values

neutral_values = create_ultra_safe_neutral_values(df, device, text_embedding_dim)
# Out:
# Directors_mapped 중립값: 1 (Unknown 사용)
# Producers_mapped 중립값: 1 (Unknown 사용)
# Cast_mapped 중립값: 1 (Unknown 사용)

# %%
def calculate_ultra_safe_feature_importance(model, inputs, device):
    """
    완전히 안전한 Feature 중요도 측정
    """
    model.eval()

    with torch.no_grad():
        baseline_score = model(*[t.to(device) for t in inputs]).cpu().item()

    importances = {}
    feature_names = ['Directors', 'Producers', 'Cast', 'Numericals', 'DescriptionEmbedding', 'TitleEmbedding']

    for i, name in enumerate(feature_names):
        try:
            ablated_inputs = [t.clone().to(device) for t in inputs]
            feature_idx = i + 2

            if name == 'Numericals':
                neutral_tensor = torch.tensor([[
                    neutral_values['norm_runtime'],
                    neutral_values['norm_year'],
                    neutral_values['norm_average_rating']
                ]], dtype=torch.float32).to(device)
            elif name == 'DescriptionEmbedding':
                neutral_tensor = neutral_values['description_embedding'].unsqueeze(0).to(device)
            elif name == 'TitleEmbedding':
                neutral_tensor = neutral_values['title_embedding'].unsqueeze(0).to(device)
            else:
                neutral_tensor = torch.LongTensor([neutral_values[f'{name}_mapped']]).to(device)

            ablated_inputs[feature_idx] = neutral_tensor

            with torch.no_grad():
                ablated_score = model(*ablated_inputs).cpu().item()

            importances[name] = baseline_score - ablated_score

        except Exception as e:
            print(f"Feature {name} ablation 오류: {e}")
            importances[name] = 0.0

    return importances, baseline_score

# %%
# **사전 통계 계산 (속도 최적화)**
print("사전 통계 계산 중...")
df_stats = {
    'director_ratings': {},
    'producer_ratings': {},
    'cast_ratings': {}
}

# Directors 평균 평점 계산
for director in df['Directors'].unique():
    if director != 'Unknown':
        director_movies = df[df['Directors'] == director]
        if len(director_movies) > 0:
            avg_rating = director_movies['average_rating'].mean()
            df_stats['director_ratings'][director] = min(avg_rating / 5.0, 1.0)

# Producers 평균 평점 계산
for producer in df['Producers'].unique():
    if producer != 'Unknown':
        producer_movies = df[df['Producers'] == producer]
        if len(producer_movies) > 0:
            avg_rating = producer_movies['average_rating'].mean()
            df_stats['producer_ratings'][producer] = min(avg_rating / 5.0, 1.0)

# Cast 평균 평점 계산
for cast in df['Cast'].unique():
    if cast != 'Unknown':
        cast_movies = df[df['Cast'] == cast]
        if len(cast_movies) > 0:
            avg_rating = cast_movies['average_rating'].mean()
            df_stats['cast_ratings'][cast] = min(avg_rating / 5.0, 1.0)

print("사전 통계 계산 완료")
# Out:
# 사전 통계 계산 중...
# 사전 통계 계산 완료

# %%
def calculate_optimized_movie_appeal(movie_info, df_stats):
    """
    최적화된 영화 매력도 계산
    """
    appeal_scores = {}

    # Directors 매력도
    director = movie_info.get('Directors', 'Unknown')
    appeal_scores['Directors'] = df_stats['director_ratings'].get(director, 0.6)

    # Producers 매력도
    producer = movie_info.get('Producers', 'Unknown')
    appeal_scores['Producers'] = df_stats['producer_ratings'].get(producer, 0.6)

    # Cast 매력도
    cast = movie_info.get('Cast', 'Unknown')
    appeal_scores['Cast'] = df_stats['cast_ratings'].get(cast, 0.6)

    # Numericals 매력도
    runtime_score = 0.8 if 90 <= movie_info.get('Runtime_min', 0) <= 150 else 0.4
    year_score = min(max((movie_info.get('year', 1990) - 1990) / 30, 0), 1)
    rating_score = movie_info.get('average_rating', 3.0) / 5.0
    appeal_scores['Numericals'] = (runtime_score + year_score + rating_score) / 3

    # Text 매력도
    base_appeal = movie_info.get('average_rating', 3.0) / 5.0
    appeal_scores['DescriptionEmbedding'] = base_appeal
    appeal_scores['TitleEmbedding'] = base_appeal

    return appeal_scores

# %%
# **단계별 안전한 텐서 변환 함수**
def step_by_step_safe_conversion(item_info, user_id, item_id, device, text_embedding_dim):
    """
    단계별로 안전하게 텐서를 생성하는 함수
    """
    inputs = []

    try:
        # 1. User ID
        user_tensor = torch.LongTensor([user_id]).to(device)
        inputs.append(user_tensor)

        # 2. Item ID
        item_tensor = torch.LongTensor([item_id]).to(device)
        inputs.append(item_tensor)

        # 3. Directors
        director_val = int(item_info['Directors_mapped'])
        director_tensor = torch.LongTensor([director_val]).to(device)
        inputs.append(director_tensor)

        # 4. Producers
        producer_val = int(item_info['Producers_mapped'])
        producer_tensor = torch.LongTensor([producer_val]).to(device)
        inputs.append(producer_tensor)

        # 5. Cast
        cast_val = int(item_info['Cast_mapped'])
        cast_tensor = torch.LongTensor([cast_val]).to(device)
        inputs.append(cast_tensor)

        # 6. Numerical features - 안전한 처리
        try:
            runtime_val = float(item_info['norm_runtime'])
            year_val = float(item_info['norm_year'])
            rating_val = float(item_info['norm_average_rating'])

            numerical_array = np.array([runtime_val, year_val, rating_val], dtype=np.float32)
            numerical_tensor = torch.tensor(numerical_array, dtype=torch.float32).unsqueeze(0).to(device)
            inputs.append(numerical_tensor)
        except Exception as e:
            print(f"    6. Numerical 텐서 생성 실패: {e}")
            raise e

        # 7. Description embedding
        desc_emb = item_info['emb_description']
        desc_tensor = torch.tensor(desc_emb, dtype=torch.float32).unsqueeze(0).to(device)
        inputs.append(desc_tensor)

        # 8. Title embedding
        title_emb = item_info['emb_title']
        title_tensor = torch.tensor(title_emb, dtype=torch.float32).unsqueeze(0).to(device)
        inputs.append(title_tensor)

        return inputs

    except Exception as e:
        print(f"    ❌ 텐서 생성 실패: {e}")
        raise e

# %%
# 사용자 프로필 계산

def calculate_final_user_profile(model, user_id, train_df, all_items_df, device, text_embedding_dim, top_k_analysis=10):
    """
    완전한 사용자 Feature 프로필 계산
    """
    user_high_rated = train_df[
        (train_df['user_id_mapped'] == user_id) &
        (train_df['rating'] >= 4.0)
    ]

    if len(user_high_rated) < 3:
        print(f"사용자 {user_id}: 고평점 영화가 {len(user_high_rated)}개로 부족함")
        return None

    print(f"사용자 {user_id}: {len(user_high_rated)}개 고평점 영화 중 상위 {min(top_k_analysis, len(user_high_rated))}개 분석")

    feature_importance_list = []
    success_count = 0

    for idx, (_, item_row) in enumerate(user_high_rated.head(top_k_analysis).iterrows()):
        item_id = item_row['asin_mapped']

        try:
            item_info = all_items_df.loc[item_id]

            # 단계별 안전한 텐서 생성
            inputs_for_ablation = step_by_step_safe_conversion(
                item_info, user_id, item_id, device, text_embedding_dim
            )

            # Feature Ablation 수행
            feature_importances, _ = calculate_ultra_safe_feature_importance(model, inputs_for_ablation, device)
            feature_importance_list.append(feature_importances)
            success_count += 1
            print(f"  ✅ 영화 {item_id} 분석 성공!")

        except Exception as e:
            print(f"  ❌ 영화 {item_id} 처리 중 오류 (건너뜀): {e}")
            continue

    if not feature_importance_list:
        print(f"사용자 {user_id}: 분석 가능한 영화가 없음 (성공: {success_count}/{top_k_analysis})")
        return None

    print(f"사용자 {user_id}: {success_count}/{top_k_analysis}개 영화 분석 성공")

    # 평균 feature 중요도 계산
    avg_importance = {}
    feature_names = ['Directors', 'Producers', 'Cast', 'Numericals', 'DescriptionEmbedding', 'TitleEmbedding']

    for feature in feature_names:
        importance_values = [fi[feature] for fi in feature_importance_list if feature in fi]
        avg_importance[feature] = np.mean(importance_values) if importance_values else 0

    primary_feature = max(avg_importance, key=avg_importance.get)

    return {
        'user_id': user_id,
        'feature_profile': avg_importance,
        'primary_feature': primary_feature,
        'analysis_based_on': len(feature_importance_list),
        'confidence_score': max(avg_importance.values()) if avg_importance else 0,
        'success_rate': success_count / top_k_analysis
    }

# %%
# **완전한 가중치 기반 추천 생성**
def generate_final_recommendations(model, user_profile, user_item_train, all_items_df, df_stats, K=5, device='cuda'):
    """
    완전한 가중치 기반 추천 생성
    """
    user_id = user_profile['user_id']
    feature_weights = user_profile['feature_profile']

    print(f"사용자 {user_id}의 완전한 개인화 추천 생성")

    # 후보 영화들 선택
    seen_items = user_item_train.get(user_id, set())
    candidate_items_df = all_items_df[~all_items_df.index.isin(seen_items)]

    if candidate_items_df.empty:
        return []

    # 안전한 배치 처리
    all_item_ids = candidate_items_df.index.values
    batch_size_final = min(2000, len(all_item_ids))  # 안전한 배치 사이즈

    u_tensor = torch.LongTensor([user_id] * batch_size_final).to(device)
    i_tensor = torch.LongTensor(all_item_ids[:batch_size_final]).to(device)

    candidate_subset = candidate_items_df.iloc[:batch_size_final]
    d_tensor = torch.LongTensor(candidate_subset['Directors_mapped'].values).to(device)
    p_tensor = torch.LongTensor(candidate_subset['Producers_mapped'].values).to(device)
    c_tensor = torch.LongTensor(candidate_subset['Cast_mapped'].values).to(device)

    # 안전한 수치형 텐서 변환
    num_tensor = torch.FloatTensor(candidate_subset[['norm_runtime', 'norm_year', 'norm_average_rating']].values).to(device)

    # **완전히 안전한 임베딩 텐서 변환**
    desc_tensor = torch.FloatTensor(ultra_safe_embedding_stack(candidate_subset['emb_description'], text_embedding_dim)).to(device)
    title_tensor = torch.FloatTensor(ultra_safe_embedding_stack(candidate_subset['emb_title'], text_embedding_dim)).to(device)

    with torch.no_grad():
        base_predictions = model(u_tensor, i_tensor, d_tensor, p_tensor, c_tensor, num_tensor, desc_tensor, title_tensor)

    # 개인화 점수 계산
    enhanced_scores = []

    for i, item_id in enumerate(all_item_ids[:batch_size_final]):
        item_info = candidate_subset.iloc[i]
        base_score = base_predictions[i].cpu().item()

        # 영화 매력도 계산
        movie_appeal = calculate_optimized_movie_appeal(item_info, df_stats)

        # 가중 평균으로 개인화 보너스 계산
        personalized_bonus = sum(
            max(feature_weights.get(feature, 0), 0) * movie_appeal.get(feature, 0.5)
            for feature in feature_weights.keys()
        ) / len(feature_weights)

        final_score = base_score + (personalized_bonus - 0.5) * 0.4

        enhanced_scores.append((item_id, final_score, base_score, personalized_bonus, movie_appeal))

    # Top-K 선택
    enhanced_scores.sort(key=lambda x: x[1], reverse=True)
    top_k_scores = enhanced_scores[:K]

    recommendations = []
    for rank, (item_id, final_score, base_score, personalized_bonus, movie_appeal) in enumerate(top_k_scores, 1):
        item_info = all_items_df.loc[item_id]

        # 가장 기여도가 높은 feature 찾기
        weighted_contributions = {
            feature: feature_weights.get(feature, 0) * movie_appeal.get(feature, 0)
            for feature in feature_weights.keys()
        }
        top_contributing_feature = max(weighted_contributions, key=weighted_contributions.get)

        recommendations.append({
            'rank': rank,
            'asin_mapped': item_id,
            'asin': item_info['asin'],
            'title': item_info['title'],
            'predicted_rating': float(final_score),
            'base_rating': float(base_score),
            'personalization_bonus': float(personalized_bonus),
            'recommended_based_on': top_contributing_feature,
            'feature_contributions': weighted_contributions,
            'movie_appeal_scores': movie_appeal,
            'user_feature_profile': feature_weights,
            'profile_confidence': user_profile['confidence_score'],
            'directors': item_info.get('Directors', 'Unknown'),
            'producers': item_info.get('Producers', 'Unknown'),
            'cast': item_info.get('Cast', 'Unknown'),
            'average_rating': item_info.get('average_rating', 'Unknown')
        })

    return recommendations

# %%
# **최종 완전한 추천 시스템**
def generate_complete_final_system(model, user_item_train, train_df, all_items_df, user_ids, K=5, device='cuda'):
    """
    최종 완전한 가중치 기반 개인화 추천 시스템
    """
    model.eval()
    final_results = []

    print(f"=== {len(user_ids)}명 사용자에 대한 최종 완전한 추천 시스템 ===")

    for user_id in tqdm(user_ids, desc="최종 완전한 추천 생성"):
        try:
            # 1. 사용자 Feature 프로필 생성
            user_profile = calculate_final_user_profile(
                model, user_id, train_df, all_items_df, device, text_embedding_dim
            )

            if user_profile is None:
                continue

            # 2. 완전한 가중치 기반 추천 생성
            user_recommendations = generate_final_recommendations(
                model, user_profile, user_item_train, all_items_df, df_stats, K, device
            )

            if not user_recommendations:
                continue

            # 3. 최종 결과 저장
            user_info = train_df[train_df['user_id_mapped'] == user_id].iloc[0]
            final_results.append({
                'user_id': user_info['user_id'],
                'user_id_mapped': user_id,
                'user_profile': user_profile,
                'recommendation_candidates': user_recommendations
            })

        except Exception as e:
            print(f"사용자 {user_id} 처리 중 오류 발생: {e}")
            continue

    return final_results

# %%
# **최종 추천 시스템 실행**
print("=== 최종 완전한 추천 시스템 실행 ===")

unique_users_in_val = val_df['user_id_mapped'].unique()
# final_users = unique_users_in_val[:50]  # 50명으로 확장

'''
final_complete_results = generate_complete_final_system(
    model, user_item_train, train_df, all_items_df, final_users, K=5, device=device
)
'''

final_complete_results = generate_complete_final_system(
    model, user_item_train, train_df, all_items_df, unique_users_in_val, K=5, device=device
)


if final_complete_results:
    # 결과 저장
    final_df = pd.DataFrame(final_complete_results)
    output_path = '/content/drive/MyDrive/데사경영학술제/result_data/amazon_recommendation_ablation.pkl'
    final_df.to_pickle(output_path)

    print(f"\n🎉 최종 완전한 추천 결과 저장: {output_path}")
    print(f"총 {len(final_df)}명의 사용자에 대한 완전한 개인화 추천 완료!")

    # **최종 결과 상세 출력**
    print("\n=== 최종 완전한 추천 시스템 결과 ===")

    # 사용자 유형 분포 분석
    feature_distribution = {}
    for _, row in final_df.iterrows():
        primary_feature = row['user_profile']['primary_feature']
        feature_distribution[primary_feature] = feature_distribution.get(primary_feature, 0) + 1

    print("🎯 사용자 유형 분포:")
    for feature, count in sorted(feature_distribution.items(), key=lambda x: x[1], reverse=True):
        print(f"  {feature} 중심 사용자: {count}명 ({count/len(final_df)*100:.1f}%)")

    # 샘플 결과 출력
    print(f"\n📋 샘플 추천 결과 (처음 3명):")
    for i, row in final_df.head(3).iterrows():
        user_profile = row['user_profile']
        print(f"\n--- 사용자 {row['user_id']} ---")
        print(f"🎯 주요 특성: {user_profile['primary_feature']} (신뢰도: {user_profile['confidence_score']:.3f})")
        print(f"📊 성공률: {user_profile['success_rate']:.2%}")
        print(f"📈 Feature 가중치: {user_profile['feature_profile']}")

        print(f"\n🎬 개인화 추천 영화:")
        for rec in row['recommendation_candidates']:
            print(f"  {rec['rank']}. {rec['title']}")
            print(f"     최종: {rec['predicted_rating']:.3f} (기본: {rec['base_rating']:.3f} + 보너스: {rec['personalization_bonus']:.3f})")
            print(f"     추천 이유: {rec['recommended_based_on']} 특성 기반")
            print(f"     평균 별점: {rec['average_rating']}")

    print(f"\n🏆 최종 성과 요약:")
    print(f"  ✅ 총 {len(final_df)}명 사용자 프로필 생성 성공")
    print(f"  ✅ 개인화된 Feature 기반 추천 완료")
    print(f"  ✅ Title + 평균별점 반영 완료")
    print(f"  ✅ 가중치 기반 개인화 달성")
    print(f"  ✅ Object 타입 오류 완전 해결")

    print("\n🎉 모든 개선사항을 반영한 최종 완전한 추천 시스템이 성공적으로 완료되었습니다!")

else:
    print("⚠️ 추천 결과 생성에 실패했습니다.")

print("\n" + "="*80)
print("🎊 축하합니다! 지금까지 의논한 모든 사항이 완벽하게 반영된")
print("   최종 완전한 가중치 기반 개인화 추천 시스템이 완성되었습니다! 🎊")
print("="*80)
# Out:
# === 최종 완전한 추천 시스템 실행 ===
# === 1932명 사용자에 대한 최종 완전한 추천 시스템 ===
# 최종 완전한 추천 생성:   0%|          | 0/1932 [00:00<?, ?it/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 3500 분석 성공!
#   ✅ 영화 296 분석 성공!
#   ✅ 영화 5750 분석 성공!
#   ✅ 영화 5748 분석 성공!
#   ✅ 영화 5749 분석 성공!
#   ✅ 영화 5631 분석 성공!
# 사용자 1348: 6/10개 영화 분석 성공
# 사용자 1348의 완전한 개인화 추천 생성
# 사용자 1349: 고평점 영화가 2개로 부족함
# 사용자 1350: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 5754 분석 성공!
#   ✅ 영화 1569 분석 성공!
#   ✅ 영화 481 분석 성공!
#   ✅ 영화 2717 분석 성공!
#   ✅ 영화 5753 분석 성공!
# 사용자 1350: 5/10개 영화 분석 성공
# 사용자 1350의 완전한 개인화 추천 생성
# 사용자 1351: 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 4191 분석 성공!
#   ✅ 영화 2545 분석 성공!
#   ✅ 영화 5756 분석 성공!
#   ✅ 영화 730 분석 성공!
#   ✅ 영화 4025 분석 성공!
#   ✅ 영화 284 분석 성공!
# 사용자 1351: 6/10개 영화 분석 성공
# 사용자 1351의 완전한 개인화 추천 생성
# 사용자 1352: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 320 분석 성공!
#   ✅ 영화 5281 분석 성공!
#   ✅ 영화 1681 분석 성공!
#   ✅ 영화 1907 분석 성공!
#   ✅ 영화 492 분석 성공!
# 사용자 1352: 5/10개 영화 분석 성공
# 사용자 1352의 완전한 개인화 추천 생성
# 사용자 1353: 7개 고평점 영화 중 상위 7개 분석
#   ✅ 영화 228 분석 성공!
#   ✅ 영화 1515 분석 성공!
#   ✅ 영화 946 분석 성공!
#   ✅ 영화 1463 분석 성공!
#   ✅ 영화 3595 분석 성공!
#   ✅ 영화 3800 분석 성공!
#   ✅ 영화 1498 분석 성공!
# 사용자 1353: 7/10개 영화 분석 성공
# 사용자 1353의 완전한 개인화 추천 생성
# 사용자 1354: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 3539 분석 성공!
#   ✅ 영화 1795 분석 성공!
#   ✅ 영화 1329 분석 성공!
#   ✅ 영화 2616 분석 성공!
#   ✅ 영화 4315 분석 성공!
# 사용자 1354: 5/10개 영화 분석 성공
# 사용자 1354의 완전한 개인화 추천 생성
# 사용자 1355: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 5761 분석 성공!
#   ✅ 영화 3097 분석 성공!
#   ✅ 영화 1060 분석 성공!
#   ✅ 영화 5760 분석 성공!
# 사용자 1355: 4/10개 영화 분석 성공
# 사용자 1355의 완전한 개인화 추천 생성
# 사용자 1356: 7개 고평점 영화 중 상위 7개 분석
#   ✅ 영화 224 분석 성공!
#   ✅ 영화 5762 분석 성공!
#   ✅ 영화 5205 분석 성공!
#   ✅ 영화 566 분석 성공!
#   ✅ 영화 884 분석 성공!
#   ✅ 영화 2257 분석 성공!
#   ✅ 영화 3082 분석 성공!
# 사용자 1356: 7/10개 영화 분석 성공
# 사용자 1356의 완전한 개인화 추천 생성
# 사용자 1357: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 1132 분석 성공!
#   ✅ 영화 3880 분석 성공!
#   ✅ 영화 4347 분석 성공!
#   ✅ 영화 1838 분석 성공!
#   ✅ 영화 861 분석 성공!
# 사용자 1357: 5/10개 영화 분석 성공
# 사용자 1357의 완전한 개인화 추천 생성
# 사용자 1358: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 681 분석 성공!
#   ✅ 영화 5765 분석 성공!
#   ✅ 영화 3390 분석 성공!
#   ✅ 영화 2942 분석 성공!
#   ✅ 영화 852 분석 성공!
#   ✅ 영화 4903 분석 성공!
#   ✅ 영화 3525 분석 성공!
#   ✅ 영화 1724 분석 성공!
# 사용자 1358: 8/10개 영화 분석 성공
# 사용자 1358의 완전한 개인화 추천 생성
# 사용자 1359: 고평점 영화가 1개로 부족함
# 사용자 1360: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 
 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 1235 분석 성공!
#   ✅ 영화 1882 분석 성공!
#   ✅ 영화 713 분석 성공!
#   ✅ 영화 1336 분석 성공!
#   ✅ 영화 1285 분석 성공!
#   ✅ 영화 1065 분석 성공!
# 사용자 1399: 6/10개 영화 분석 성공
# 사용자 1399의 완전한 개인화 추천 생성
# 사용자 1400: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 2620 분석 성공!
#   ✅ 영화 933 분석 성공!
#   ✅ 영화 5831 분석 성공!
# 사용자 1400: 3/10개 영화 분석 성공
# 사용자 1400의 완전한 개인화 추천 생성
# 사용자 1401: 고평점 영화가 2개로 부족함
# 사용자 1402: 고평점 영화가 2개로 부족함
# 사용자 1403: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 3528 분석 성공!
#   ✅ 영화 3081 분석 성공!
#   ✅ 영화 5840 분석 성공!
#   ✅ 영화 1615 분석 성공!
# 사용자 1403: 4/10개 영화 분석 성공
# 사용자 1403의 완전한 개인화 추천 생성
# 사용자 1404: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 681 분석 성공!
#   ✅ 영화 11 분석 성공!
#   ✅ 영화 5841 분석 성공!
#   ✅ 영화 1089 분석 성공!
#   ✅ 영화 1154 분석 성공!
# 사용자 1404: 5/10개 영화 분석 성공
# 사용자 1404의 완전한 개인화 추천 생성
# 사용자 1405: 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 4550 분석 성공!
#   ✅ 영화 3212 분석 성공!
#   ✅ 영화 1059 분석 성공!
#   ✅ 영화 284 분석 성공!
#   ✅ 영화 727 분석 성공!
#   ✅ 영화 440 분석 성공!
# 사용자 1405: 6/10개 영화 분석 성공
# 사용자 1405의 완전한 개인화 추천 생성
# 사용자 1406: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 3343 분석 성공!
#   ✅ 영화 1269 분석 성공!
#   ✅ 영화 203 분석 성공!
#   ✅ 영화 3886 분석 성공!
# 사용자 1406: 4/10개 영화 분석 성공
# 사용자 1406의 완전한 개인화 추천 생성
# 사용자 1407: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 4717 분석 성공!
#   ✅ 영화 5194 분석 성공!
#   ✅ 영화 1268 분석 성공!
#   ✅ 영화 5668 분석 성공!
# 사용자 1407: 4/10개 영화 분석 성공
# 사용자 1407의 완전한 개인화 추천 생성
# 사용자 1408: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 1803 분석 성공!
#   ✅ 영화 5844 분석 성공!
#   ✅ 영화 4055 분석 성공!
#   ✅ 영화 5838 분석 성공!
# 사용자 1408: 4/10개 영화 분석 성공
# 사용자 1408의 완전한 개인화 추천 생성
# 사용자 1409: 20개 고평점 영화 중 상위 10개 분석
#   ✅ 영화 2615 분석 성공!
#   ✅ 영화 88 분석 성공!
#   ✅ 영화 1612 분석 성공!
#   ✅ 영화 1511 분석 성공!
#   ✅ 영화 2703 분석 성공!
#   ✅ 영화 933 분석 성공!
#   ✅ 영화 93 분석 성공!
#   ✅ 영화 199 분석 성공!
#   ✅ 영화 4053 분석 성공!
#   ✅ 영화 5846 분석 성공!
# 사용자 1409: 10/10개 영화 분석 성공
# 사용자 1409의 완전한 개인화 추천 생성
# 사용자 1410: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 3974 분석 성공!
#   ✅ 영화 1305 분석 성공!
#   ✅ 영화 900 분석 성공!
# 사용자 1410: 3/10개 영화 분석 성공
# 사용자 1410의 완전한 개인화 추천 생성
# 사용자 1411: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화
 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 204 분석 성공!
#   ✅ 영화 2850 분석 성공!
#   ✅ 영화 253 분석 성공!
#   ✅ 영화 3862 분석 성공!
#   ✅ 영화 1724 분석 성공!
#   ✅ 영화 202 분석 성공!
#   ✅ 영화 5872 분석 성공!
#   ✅ 영화 381 분석 성공!
# 사용자 1430: 8/10개 영화 분석 성공
# 사용자 1430의 완전한 개인화 추천 생성
# 사용자 1431: 9개 고평점 영화 중 상위 9개 분석
#   ✅ 영화 695 분석 성공!
#   ✅ 영화 559 분석 성공!
#   ✅ 영화 1212 분석 성공!
#   ✅ 영화 3242 분석 성공!
#   ✅ 영화 60 분석 성공!
#   ✅ 영화 795 분석 성공!
#   ✅ 영화 1222 분석 성공!
#   ✅ 영화 5873 분석 성공!
#   ✅ 영화 2274 분석 성공!
# 사용자 1431: 9/10개 영화 분석 성공
# 사용자 1431의 완전한 개인화 추천 생성
# 사용자 1432: 고평점 영화가 2개로 부족함
# 사용자 1433: 고평점 영화가 1개로 부족함
# 사용자 1434: 고평점 영화가 2개로 부족함
# 사용자 1435: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 1681 분석 성공!
#   ✅ 영화 5880 분석 성공!
#   ✅ 영화 5881 분석 성공!
#   ✅ 영화 1811 분석 성공!
# 사용자 1435: 4/10개 영화 분석 성공
# 사용자 1435의 완전한 개인화 추천 생성
# 사용자 1436: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 1329 분석 성공!
#   ✅ 영화 3176 분석 성공!
#   ✅ 영화 1024 분석 성공!
#   ✅ 영화 94 분석 성공!
# 사용자 1436: 4/10개 영화 분석 성공
# 사용자 1436의 완전한 개인화 추천 생성
# 사용자 1437: 고평점 영화가 1개로 부족함
# 사용자 1438: 고평점 영화가 0개로 부족함
# 사용자 1439: 7개 고평점 영화 중 상위 7개 분석
#   ✅ 영화 4786 분석 성공!
#   ✅ 영화 5886 분석 성공!
#   ✅ 영화 924 분석 성공!
#   ✅ 영화 5885 분석 성공!
#   ✅ 영화 695 분석 성공!
#   ✅ 영화 1726 분석 성공!
#   ✅ 영화 813 분석 성공!
# 사용자 1439: 7/10개 영화 분석 성공
# 사용자 1439의 완전한 개인화 추천 생성
# 사용자 1440: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 787 분석 성공!
#   ✅ 영화 3758 분석 성공!
#   ✅ 영화 939 분석 성공!
# 사용자 1440: 3/10개 영화 분석 성공
# 사용자 1440의 완전한 개인화 추천 생성
# 사용자 1441: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 1400 분석 성공!
#   ✅ 영화 3528 분석 성공!
#   ✅ 영화 5889 분석 성공!
#   ✅ 영화 5888 분석 성공!
#   ✅ 영화 2168 분석 성공!
# 사용자 1441: 5/10개 영화 분석 성공
# 사용자 1441의 완전한 개인화 추천 생성
# 사용자 1442: 12개 고평점 영화 중 상위 10개 분석
#   ✅ 영화 716 분석 성공!
#   ✅ 영화 5242 분석 성공!
#   ✅ 영화 1418 분석 성공!
#   ✅ 영화 4688 분석 성공!
#   ✅ 영화 2873 분석 성공!
#   ✅ 영화 1750 분석 성공!
#   ✅ 영화 5890 분석 성공!
#   ✅ 영화 3591 분석 성공!
#   ✅ 영화 802 분석 성공!
#   ✅ 영화 283 분석 성공!
# 사용자 1442: 10/10개 영화 분석 성공
# 사용자 1442의 완전한 개인화 추천 생성
# 사용자 1443: 고평점 영화가 2개로 부족함
# 사용자 1444: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 501 분석 성공!
#   ✅ 영화 3837 분석 성공!
#   ✅ 영화 3793 분석 성공!
#   ✅ 영화 1628 분석 성공!
#   ✅ 영화 5893 분석 성공!
#   ✅ 영화 5894 분석 성공!
#   ✅ 영화 5563 분석 성공!
#   ✅ 영화 1303 분석 성공!
# 사용자 1444: 8/10개 영화 분석 성공
# 사용자 1444의 완전한 개인화 추천 생성
# 사용자 1445: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 615 분석 성공!
#   ✅ 영화 5810 분석 성공!
#   ✅ 영화 573 분석 성공!
#   ✅ 영화 525 분석 성공!
# 사용자 1445: 4/10개 영화 분석 성공
# 사용자 1445의 완전한 개인화 추천 생성
# 사용자 1446: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 523 분석 성공!
#   ✅ 영화 2714 분석 성공!
#   ✅ 영화 2603 분석 성공!
#   ✅ 영화 4107 분석 성공!
#   ✅ 영화 5895 분석 성공!
#   ✅ 영화 5896 분석 성공!
#   ✅ 영화 4136 분석 성공!
#   ✅ 영화 3967 분석 성공!
# 사용자 1446: 8/10개 영화 분석 성공
# 사용자 1446의 완전한 개인화 추천 생성
# 사용자 1447: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 5898 분석 성공!
#   ✅ 영화 5897 분석 성공!
#   ✅ 영화 2253 분석 성공!
#   ✅ 영화 2221 분석 성공!
#   ✅ 영화 2620 분석 성공!
# 사용자 1447: 5/10개 영화 분석 성공
# 사용자 1447의 완전한 개인화 추천 생성
# 사용자 1448: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 4479 분석 성공!
#   ✅ 영화 215 분석 성공!
#   ✅ 영화 4061 분석 성공!
# 사용자 1448: 3/10개 영화 분석 성공
# 사용자 1448의 완전한 개인화 추천 생성
# 사용자 1449: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 2655 분석 성공!
#   ✅ 영화 20 분석 성공!
#   ✅ 영화 3842 분석 성공!
# 사용자 1449: 3/10개 영화 분석 성공
# 사용자 1449의 완전한 개인화 추천 생성
# 사용자 1450: 고평점 영화가 1개로 부족함
# 사용자 1451: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 3535 분석 성공!
#   ✅ 영화 5139 분석 성공!
#   ✅ 영화 2708 분석 성공!
#   ✅ 영화 5905 분석 성공!
# 사용자 1451: 4/10개 영화 분석 성공
# 사용자 1451의 완전한 개인화 추천 생성
# 사용자 1452: 7개 고평점 영화 중 상위 7개 분석
#   ✅ 영화 951 분석 성공!
#   ✅ 영화 5432 분석 성공!
#   ✅ 영화 4345 분석 성공!
#   ✅ 영화 20 분석 성공!
#   ✅ 영화 5907 분석 성공!
#   ✅ 영화 3037 분석 성공!
#   ✅ 영화 947 분석 성공!
# 사용자 1452: 7/10개 영화 분석 성공
# 사용자 1452의 완전한 개인화 추천 생성
# 사용자 1453: 고평점 영화가 2개로 부족함
# 사용자 1454: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 1864 분석 성공!
#   ✅ 영화 1733 분석 성공!
#   ✅ 영화 781 분석 성공!
#   ✅ 영화 1902 분석 성공!
# 사용자 1454: 4/10개 영화 분석 성공
# 사용자 1454의 완전한 개인화 추천 생성
# 사용자 1455: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 604 분석 성공!
#   ✅ 영화 1680 분석 성공!
#   ✅ 영화 835 분석 성공!
# 사용자 1455: 3/10개 영화 분석 성공
# 사용자 1455의 완전한 개인화 추천 생성
# 사용자 1456: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화
 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 697 분석 성공!
#   ✅ 영화 3929 분석 성공!
#   ✅ 영화 3093 분석 성공!
#   ✅ 영화 5934 분석 성공!
#   ✅ 영화 2832 분석 성공!
#   ✅ 영화 1893 분석 성공!
# 사용자 1467: 6/10개 영화 분석 성공
# 사용자 1467의 완전한 개인화 추천 생성
# 사용자 1468: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 1187 분석 성공!
#   ✅ 영화 5637 분석 성공!
#   ✅ 영화 5935 분석 성공!
# 사용자 1468: 3/10개 영화 분석 성공
# 사용자 1468의 완전한 개인화 추천 생성
# 사용자 1469: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 5937 분석 성공!
#   ✅ 영화 4495 분석 성공!
#   ✅ 영화 3121 분석 성공!
#   ✅ 영화 3114 분석 성공!
#   ✅ 영화 3773 분석 성공!
# 사용자 1469: 5/10개 영화 분석 성공
# 사용자 1469의 완전한 개인화 추천 생성
# 사용자 1470: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 5940 분석 성공!
#   ✅ 영화 1013 분석 성공!
#   ✅ 영화 5939 분석 성공!
#   ✅ 영화 1458 분석 성공!
#   ✅ 영화 2560 분석 성공!
# 사용자 1470: 5/10개 영화 분석 성공
# 사용자 1470의 완전한 개인화 추천 생성
# 사용자 1471: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 3121 분석 성공!
#   ✅ 영화 1875 분석 성공!
#   ✅ 영화 1016 분석 성공!
#   ✅ 영화 1646 분석 성공!
#   ✅ 영화 677 분석 성공!
#   ✅ 영화 3062 분석 성공!
#   ✅ 영화 1605 분석 성공!
#   ✅ 영화 1238 분석 성공!
# 사용자 1471: 8/10개 영화 분석 성공
# 사용자 1471의 완전한 개인화 추천 생성
# 사용자 1472: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 423 분석 성공!
#   ✅ 영화 3245 분석 성공!
#   ✅ 영화 688 분석 성공!
#   ✅ 영화 1629 분석 성공!
#   ✅ 영화 3133 분석 성공!
#   ✅ 영화 2311 분석 성공!
#   ✅ 영화 1878 분석 성공!
#   ✅ 영화 683 분석 성공!
# 사용자 1472: 8/10개 영화 분석 성공
# 사용자 1472의 완전한 개인화 추천 생성
# 사용자 1473: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 981 분석 성공!
#   ✅ 영화 367 분석 성공!
#   ✅ 영화 1512 분석 성공!
#   ✅ 영화 1266 분석 성공!
# 사용자 1473: 4/10개 영화 분석 성공
# 사용자 1473의 완전한 개인화 추천 생성
# 사용자 1474: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 4189 분석 성공!
#   ✅ 영화 5218 분석 성공!
#   ✅ 영화 5942 분석 성공!
# 사용자 1474: 3/10개 영화 분석 성공
# 사용자 1474의 완전한 개인화 추천 생성
# 사용자 1475: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 210 분석 성공!
#   ✅ 영화 846 분석 성공!
#   ✅ 영화 5318 분석 성공!
#   ✅ 영화 1456 분석 성공!
# 사용자 1475: 4/10개 영화 분석 성공
# 사용자 1475의 완전한 개인화 추천 생성
# 사용자 1476: 고평점 영화가 2개로 부족함
# 사용자 1477: 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 4358 분석 성공!
#   ✅ 영화 780 분석 성공!
#   ✅ 영화 1202 분석 성공!
#   ✅ 영화 252 분석 성공!
#   ✅ 영화 1641 분석 성공!
#   ✅ 영화 3705 분석 성공!
# 사용자 1477: 6/10개 영화 분석 성공
# 사용자 1477의 완전한 개인화 추천 생성
# 사용자 1478: 9개 고평점 영화 중 상위 9개 분석
#   ✅ 영화
 7개 고평점 영화 중 상위 7개 분석
#   ✅ 영화 5975 분석 성공!
#   ✅ 영화 5974 분석 성공!
#   ✅ 영화 1521 분석 성공!
#   ✅ 영화 2878 분석 성공!
#   ✅ 영화 5105 분석 성공!
#   ✅ 영화 242 분석 성공!
#   ✅ 영화 423 분석 성공!
# 사용자 1498: 7/10개 영화 분석 성공
# 사용자 1498의 완전한 개인화 추천 생성
# 사용자 1499: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 5979 분석 성공!
#   ✅ 영화 1365 분석 성공!
#   ✅ 영화 2357 분석 성공!
# 사용자 1499: 3/10개 영화 분석 성공
# 사용자 1499의 완전한 개인화 추천 생성
# 사용자 1500: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 3955 분석 성공!
#   ✅ 영화 505 분석 성공!
#   ✅ 영화 4119 분석 성공!
#   ✅ 영화 620 분석 성공!
#   ✅ 영화 5980 분석 성공!
#   ✅ 영화 5981 분석 성공!
#   ✅ 영화 2267 분석 성공!
#   ✅ 영화 4146 분석 성공!
# 사용자 1500: 8/10개 영화 분석 성공
# 사용자 1500의 완전한 개인화 추천 생성
# 사용자 1501: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 247 분석 성공!
#   ✅ 영화 2253 분석 성공!
#   ✅ 영화 3257 분석 성공!
#   ✅ 영화 727 분석 성공!
#   ✅ 영화 1878 분석 성공!
# 사용자 1501: 5/10개 영화 분석 성공
# 사용자 1501의 완전한 개인화 추천 생성
# 사용자 1502: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화 1122 분석 성공!
#   ✅ 영화 2165 분석 성공!
#   ✅ 영화 230 분석 성공!
#   ✅ 영화 1674 분석 성공!
#   ✅ 영화 335 분석 성공!
#   ✅ 영화 1627 분석 성공!
#   ✅ 영화 1842 분석 성공!
#   ✅ 영화 3800 분석 성공!
# 사용자 1502: 8/10개 영화 분석 성공
# 사용자 1502의 완전한 개인화 추천 생성
# 사용자 1503: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 1341 분석 성공!
#   ✅ 영화 2730 분석 성공!
#   ✅ 영화 4018 분석 성공!
#   ✅ 영화 5504 분석 성공!
#   ✅ 영화 2732 분석 성공!
# 사용자 1503: 5/10개 영화 분석 성공
# 사용자 1503의 완전한 개인화 추천 생성
# 사용자 1504: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 294 분석 성공!
#   ✅ 영화 5985 분석 성공!
#   ✅ 영화 5986 분석 성공!
#   ✅ 영화 5984 분석 성공!
#   ✅ 영화 4705 분석 성공!
# 사용자 1504: 5/10개 영화 분석 성공
# 사용자 1504의 완전한 개인화 추천 생성
# 사용자 1505: 고평점 영화가 1개로 부족함
# 사용자 1506: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 2824 분석 성공!
#   ✅ 영화 795 분석 성공!
#   ✅ 영화 413 분석 성공!
#   ✅ 영화 3267 분석 성공!
# 사용자 1506: 4/10개 영화 분석 성공
# 사용자 1506의 완전한 개인화 추천 생성
# 사용자 1507: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 554 분석 성공!
#   ✅ 영화 311 분석 성공!
#   ✅ 영화 1351 분석 성공!
#   ✅ 영화 2093 분석 성공!
# 사용자 1507: 4/10개 영화 분석 성공
# 사용자 1507의 완전한 개인화 추천 생성
# 사용자 1508: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 1205 분석 성공!
#   ✅ 영화 1726 분석 성공!
#   ✅ 영화 413 분석 성공!
#   ✅ 영화 795 분석 성공!
# 사용자 1508: 4/10개 영화 분석 성공
# 사용자 1508의 완전한 개인화 추천 생성
# 사용자 1509: 8개 고평점 영화 중 상위 8개 분석
#   ✅ 영화
 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 2189 분석 성공!
#   ✅ 영화 224 분석 성공!
#   ✅ 영화 1218 분석 성공!
#   ✅ 영화 1152 분석 성공!
# 사용자 1549: 4/10개 영화 분석 성공
# 사용자 1549의 완전한 개인화 추천 생성
# 사용자 1550: 9개 고평점 영화 중 상위 9개 분석
#   ✅ 영화 6045 분석 성공!
#   ✅ 영화 6043 분석 성공!
#   ✅ 영화 2656 분석 성공!
#   ✅ 영화 3951 분석 성공!
#   ✅ 영화 5717 분석 성공!
#   ✅ 영화 2340 분석 성공!
#   ✅ 영화 944 분석 성공!
#   ✅ 영화 1354 분석 성공!
#   ✅ 영화 6046 분석 성공!
# 사용자 1550: 9/10개 영화 분석 성공
# 사용자 1550의 완전한 개인화 추천 생성
# 사용자 1551: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 1075 분석 성공!
#   ✅ 영화 604 분석 성공!
#   ✅ 영화 311 분석 성공!
#   ✅ 영화 2821 분석 성공!
# 사용자 1551: 4/10개 영화 분석 성공
# 사용자 1551의 완전한 개인화 추천 생성
# 사용자 1552: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 5010 분석 성공!
#   ✅ 영화 146 분석 성공!
#   ✅ 영화 5124 분석 성공!
#   ✅ 영화 2217 분석 성공!
#   ✅ 영화 4334 분석 성공!
# 사용자 1552: 5/10개 영화 분석 성공
# 사용자 1552의 완전한 개인화 추천 생성
# 사용자 1553: 고평점 영화가 2개로 부족함
# 사용자 1554: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 2175 분석 성공!
#   ✅ 영화 1464 분석 성공!
#   ✅ 영화 1737 분석 성공!
# 사용자 1554: 3/10개 영화 분석 성공
# 사용자 1554의 완전한 개인화 추천 생성
# 사용자 1555: 고평점 영화가 2개로 부족함
# 사용자 1556: 13개 고평점 영화 중 상위 10개 분석
#   ✅ 영화 2187 분석 성공!
#   ✅ 영화 6053 분석 성공!
#   ✅ 영화 5939 분석 성공!
#   ✅ 영화 821 분석 성공!
#   ✅ 영화 5218 분석 성공!
#   ✅ 영화 5278 분석 성공!
#   ✅ 영화 5684 분석 성공!
#   ✅ 영화 3139 분석 성공!
#   ✅ 영화 129 분석 성공!
#   ✅ 영화 5053 분석 성공!
# 사용자 1556: 10/10개 영화 분석 성공
# 사용자 1556의 완전한 개인화 추천 생성
# 사용자 1557: 7개 고평점 영화 중 상위 7개 분석
#   ✅ 영화 1222 분석 성공!
#   ✅ 영화 681 분석 성공!
#   ✅ 영화 1101 분석 성공!
#   ✅ 영화 369 분석 성공!
#   ✅ 영화 2856 분석 성공!
#   ✅ 영화 5923 분석 성공!
#   ✅ 영화 2052 분석 성공!
# 사용자 1557: 7/10개 영화 분석 성공
# 사용자 1557의 완전한 개인화 추천 생성
# 사용자 1558: 고평점 영화가 2개로 부족함
# 사용자 1559: 3개 고평점 영화 중 상위 3개 분석
#   ✅ 영화 513 분석 성공!
#   ✅ 영화 53 분석 성공!
#   ✅ 영화 544 분석 성공!
# 사용자 1559: 3/10개 영화 분석 성공
# 사용자 1559의 완전한 개인화 추천 생성
# 사용자 1560: 고평점 영화가 1개로 부족함
# 사용자 1561: 5개 고평점 영화 중 상위 5개 분석
#   ✅ 영화 1013 분석 성공!
#   ✅ 영화 1721 분석 성공!
#   ✅ 영화 1222 분석 성공!
#   ✅ 영화 5973 분석 성공!
#   ✅ 영화 803 분석 성공!
# 사용자 1561: 5/10개 영화 분석 성공
# 사용자 1561의 완전한 개인화 추천 생성
# 사용자 1562: 고평점 영화가 2개로 부족함
# 사용자 1563: 고평점 영화가 2개로 부족함
# 사용자 1564: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화
 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 6608 분석 성공!
#   ✅ 영화 107 분석 성공!
#   ✅ 영화 2216 분석 성공!
#   ✅ 영화 761 분석 성공!
# 사용자 1964: 4/10개 영화 분석 성공
# 사용자 1964의 완전한 개인화 추천 생성
# 사용자 1965: 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 1721 분석 성공!
#   ✅ 영화 2461 분석 성공!
#   ✅ 영화 6252 분석 성공!
#   ✅ 영화 2394 분석 성공!
#   ✅ 영화 4751 분석 성공!
#   ✅ 영화 3666 분석 성공!
# 사용자 1965: 6/10개 영화 분석 성공
# 사용자 1965의 완전한 개인화 추천 생성
# 사용자 1966: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 4628 분석 성공!
#   ✅ 영화 1944 분석 성공!
#   ✅ 영화 1123 분석 성공!
#   ✅ 영화 259 분석 성공!
# 사용자 1966: 4/10개 영화 분석 성공
# 사용자 1966의 완전한 개인화 추천 생성
# 사용자 1967: 6개 고평점 영화 중 상위 6개 분석
#   ✅ 영화 2237 분석 성공!
#   ✅ 영화 4090 분석 성공!
#   ✅ 영화 4053 분석 성공!
#   ✅ 영화 943 분석 성공!
#   ✅ 영화 3623 분석 성공!
#   ✅ 영화 94 분석 성공!
# 사용자 1967: 6/10개 영화 분석 성공
# 사용자 1967의 완전한 개인화 추천 생성
# 사용자 1968: 4개 고평점 영화 중 상위 4개 분석
#   ✅ 영화 6152 분석 성공!
#   ✅ 영화 6612 분석 성공!
#   ✅ 영화 1574 분석 성공!
#   ✅ 영화 6611 분석 성공!
# 사용자 1968: 4/10개 영화 분석 성공
# 사용자 1968의 완전한 개인화 추천 생성
# 사용자 1969: 고평점 영화가 2개로 부족함
#
# 🎉 최종 완전한 추천 결과 저장: /content/drive/MyDrive/데사경영학술제/result_data/amazon_recommendation_ablation.pkl
# 총 1697명의 사용자에 대한 완전한 개인화 추천 완료!
#
# === 최종 완전한 추천 시스템 결과 ===
# 🎯 사용자 유형 분포:
#   Numericals 중심 사용자: 618명 (36.4%)
#   Directors 중심 사용자: 617명 (36.4%)
#   Cast 중심 사용자: 272명 (16.0%)
#   Producers 중심 사용자: 86명 (5.1%)
#   TitleEmbedding 중심 사용자: 53명 (3.1%)
#   DescriptionEmbedding 중심 사용자: 51명 (3.0%)
#
# 📋 샘플 추천 결과 (처음 3명):
#
# --- 사용자 AFZUK3MTBIBEDQOPAK3OATUOUKLA ---
# 🎯 주요 특성: Numericals (신뢰도: 0.252)
# 📊 성공률: 80.00%
# 📈 Feature 가중치: {'Directors': np.float64(0.1849433183670044), 'Producers': np.float64(0.07935324311256409), 'Cast': np.float64(-0.003127485513687134), 'Numericals': np.float64(0.25182104110717773), 'DescriptionEmbedding': np.float64(-0.10780182480812073), 'TitleEmbedding': np.float64(-0.06423500180244446)}
#
# 🎬 개인화 추천 영화:
#   1. Duck Dynasty
#      최종: 4.659 (기본: 4.834 + 보너스: 0.062)
#      추천 이유: Directors 특성 기반
#      평균 별점: 4.900000095367432
#   2. Suits
#      최종: 4.621 (기본: 4.799 + 보너스: 0.056)
#      추천 이유: Directors 특성 기반
#      평균 별점: 4.800000190734863
#   3. Trapped [English Subtitled]
#      최종: 4.620 (기본: 4.796 + 보너스: 0.058)
#      추천 이유: Directors 특성 기반
#      평균 별점: 4.5
#   4. The Sixth Sense
#      최종: 4.596 (기본: 4.769 + 보너스: 0.066)
#      추천 이유: Directors 특성 기반
#      평균 별점: 4.800000190734863
#   5. Love Affair - 1939
#      최종: 4.592 (기본: 4.768 + 보너스: 0.059)
#      추천 이유: Directors 특성 기반
#      평균 별점: 4.599999904632568
#
# --- 사용자 AEYE3LSUHQEX6BWG224MKVXX6XZQ ---
# 🎯 주요 특성: Cast (신뢰도: 0.173)
# 📊 성공률: 40.00%
# 📈 Feature 가중치: {'Directors': np.float64(0.04134166240692139), 'Producers': np.float64(0.07297849655151367), 'Cast': np.float64(0.1731100082397461), 'Numericals': np.float64(0.10462784767150879), 'DescriptionEmbedding': np.float64(0.060206055641174316), 'TitleEmbedding': np.float64(-0.07365942001342773)}
#
# 🎬 개인화 추천 영화:
#   1. Night and Day (1946)
#      최종: 4.668 (기본: 4.843 + 보너스: 0.062)
#      추천 이유: Cast 특성 기반
#      평균 별점: 4.5
#   2. Suits
#      최종: 4.664 (기본: 4.841 + 보너스: 0.059)
#      추천 이유: Cast 특성 기반
#      평균 별점: 4.800000190734863
#   3. The Golden Girls
#      최종: 4.632 (기본: 4.808 + 보너스: 0.060)
#      추천 이유: Cast 특성 기반
#      평균 별점: 4.900000095367432
#   4. Dr. Quinn Medicine Woman
#      최종: 4.628 (기본: 4.803 + 보너스: 0.063)
#      추천 이유: Cast 특성 기반
#      평균 별점: 4.800000190734863
#   5. Khartoum
#      최종: 4.609 (기본: 4.783 + 보너스: 0.063)
#      추천 이유: Cast 특성 기반
#      평균 별점: 4.599999904632568
#
# --- 사용자 AHU2GG5RF6YAEWUFNLH3QH5RHDNQ ---
# 🎯 주요 특성: Numericals (신뢰도: 0.131)
# 📊 성공률: 100.00%
# 📈 Feature 가중치: {'Directors': np.float64(-0.03456854820251465), 'Producers': np.float64(-0.005419921875), 'Cast': np.float64(-0.05085875988006592), 'Numericals': np.float64(0.13111262321472167), 'DescriptionEmbedding': np.float64(-0.06523716449737549), 'TitleEmbedding': np.float64(-0.048245906829833984)}
#
# 🎬 개인화 추천 영화:
#   1. Suits
#      최종: 4.687 (기본: 4.883 + 보너스: 0.010)
#      추천 이유: Numericals 특성 기반
#      평균 별점: 4.800000190734863
#   2. Aladdin (Plus Bonus Features)
#      최종: 4.667 (기본: 4.863 + 보너스: 0.010)
#      추천 이유: Numericals 특성 기반
#      평균 별점: 4.800000190734863
#   3. Night and Day (1946)
#      최종: 4.666 (기본: 4.861 + 보너스: 0.012)
#      추천 이유: Numericals 특성 기반
#      평균 별점: 4.5
#   4. Sense And Sensibility
#      최종: 4.648 (기본: 4.843 + 보너스: 0.013)
#      추천 이유: Numericals 특성 기반
#      평균 별점: 4.800000190734863
#   5. Justified
#      최종: 4.638 (기본: 4.834 + 보너스: 0.010)
#      추천 이유: Numericals 특성 기반
#      평균 별점: 4.900000095367432
#
# 🏆 최종 성과 요약:
#   ✅ 총 1697명 사용자 프로필 생성 성공
#   ✅ 개인화된 Feature 기반 추천 완료
#   ✅ Title + 평균별점 반영 완료
#   ✅ 가중치 기반 개인화 달성
#   ✅ Object 타입 오류 완전 해결
#
# 🎉 모든 개선사항을 반영한 최종 완전한 추천 시스템이 성공적으로 완료되었습니다!
#
# ================================================================================
# 🎊 축하합니다! 지금까지 의논한 모든 사항이 완벽하게 반영된
#    최종 완전한 가중치 기반 개인화 추천 시스템이 완성되었습니다! 🎊
# ================================================================================

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# **결과 분석**

# %%
# **최종 추천 결과 확인 및 출력 코드**

def print_final_recommendations(df):
    """
    최종 추천 결과 DataFrame을 받아서 상세 정보 출력
    """
    total_users = len(df)
    print(f"=== 총 {total_users}명 사용자의 최종 추천 결과 ===\n")

    # 사용자 유형 분포 분석
    feature_distribution = {}
    for _, row in df.iterrows():
        if 'user_profile' in row and row['user_profile'] is not None:
            primary_feature = row['user_profile']['primary_feature']
            feature_distribution[primary_feature] = feature_distribution.get(primary_feature, 0) + 1

    print("🎯 사용자 유형 분포:")
    for feature, count in sorted(feature_distribution.items(), key=lambda x: x[1], reverse=True):
        print(f"  {feature} 중심 사용자: {count}명 ({count/total_users*100:.1f}%)")
    print()

    # 각 사용자별 상세 결과 출력
    for idx, row in df.iterrows():
        user_id = row['user_id']
        user_id_mapped = row['user_id_mapped']
        user_profile = row.get('user_profile', None)
        recs = row.get('recommendation_candidates', [])

        print(f"--- 사용자 {user_id} (ID: {user_id_mapped}) ---")

        # 사용자 프로필 정보
        if user_profile:
            print(f"🎯 주요 특성: {user_profile['primary_feature']}")
            print(f"📊 신뢰도: {user_profile['confidence_score']:.3f}")
            print(f"📈 성공률: {user_profile['success_rate']:.2%}")
            print(f"📋 분석 기반: {user_profile['analysis_based_on']}개 영화")
            print(f"📊 Feature 가중치:")
            for feature, weight in user_profile['feature_profile'].items():
                print(f"   {feature}: {weight:.3f}")
            print()

        # 추천 영화 정보
        print("🎬 추천 영화:")
        if isinstance(recs, list) and len(recs) > 0:
            for rec in recs:
                if isinstance(rec, dict):
                    print(f"  {rec.get('rank', 'N/A')}. {rec.get('title', 'Unknown Title')}")
                    print(f"     ⭐ 최종 점수: {rec.get('predicted_rating', 'N/A'):.3f}")
                    print(f"     📊 기본 점수: {rec.get('base_rating', 'N/A'):.3f}")
                    print(f"     🎯 개인화 보너스: {rec.get('personalization_bonus', 'N/A'):.3f}")
                    print(f"     🏆 추천 이유: {rec.get('recommended_based_on', 'N/A')} 특성 기반")
                    print(f"     ⭐ 평균 별점: {rec.get('average_rating', 'N/A')}")
                    print(f"     📂 ASIN: {rec.get('asin', 'N/A')}")
                    print(f"     🎭 감독: {rec.get('directors', 'Unknown')}")
                    print(f"     🎬 출연진: {rec.get('cast', 'Unknown')}")

                    if 'feature_contributions' in rec:
                        print(f"     📈 Feature 기여도:")
                        for feature, contribution in rec['feature_contributions'].items():
                            print(f"        {feature}: {contribution:.3f}")

                    if 'movie_appeal_scores' in rec:
                        print(f"     🎭 영화 매력도:")
                        for feature, appeal in rec['movie_appeal_scores'].items():
                            print(f"        {feature}: {appeal:.3f}")
                    print()
                else:
                    print(f"  {rec}")
        else:
            print("  추천 데이터가 없습니다.")

        print("-" * 50 + "\n")

# **최종 결과 통계 분석 함수**
def analyze_final_results(df):
    """
    최종 결과의 통계적 분석 수행
    """
    print("=== 최종 결과 통계 분석 ===\n")

    total_users = len(df)

    # 1. 기본 통계
    print(f"📊 기본 통계:")
    print(f"  총 사용자 수: {total_users}명")

    users_with_profile = sum(1 for _, row in df.iterrows() if row.get('user_profile') is not None)
    users_with_recs = sum(1 for _, row in df.iterrows() if len(row.get('recommendation_candidates', [])) > 0)

    print(f"  프로필 생성 성공: {users_with_profile}명 ({users_with_profile/total_users*100:.1f}%)")
    print(f"  추천 생성 성공: {users_with_recs}명 ({users_with_recs/total_users*100:.1f}%)")

    # 2. Feature 분포 분석
    feature_counts = {}
    confidence_scores = []
    success_rates = []

    for _, row in df.iterrows():
        user_profile = row.get('user_profile')
        if user_profile:
            primary = user_profile['primary_feature']
            feature_counts[primary] = feature_counts.get(primary, 0) + 1
            confidence_scores.append(user_profile['confidence_score'])
            success_rates.append(user_profile['success_rate'])

    print(f"\n🎯 Feature 분포:")
    for feature, count in sorted(feature_counts.items(), key=lambda x: x[1], reverse=True):
        print(f"  {feature}: {count}명 ({count/users_with_profile*100:.1f}%)")

    # 3. 성능 지표
    if confidence_scores and success_rates:
        print(f"\n📈 성능 지표:")
        print(f"  평균 신뢰도: {np.mean(confidence_scores):.3f}")
        print(f"  평균 성공률: {np.mean(success_rates):.2%}")
        print(f"  신뢰도 범위: {min(confidence_scores):.3f} ~ {max(confidence_scores):.3f}")
        print(f"  성공률 범위: {min(success_rates):.2%} ~ {max(success_rates):.2%}")

    # 4. 추천 품질 분석
    all_ratings = []
    all_bonuses = []

    for _, row in df.iterrows():
        recs = row.get('recommendation_candidates', [])
        for rec in recs:
            if isinstance(rec, dict):
                if 'predicted_rating' in rec:
                    all_ratings.append(rec['predicted_rating'])
                if 'personalization_bonus' in rec:
                    all_bonuses.append(rec['personalization_bonus'])

    if all_ratings:
        print(f"\n🎬 추천 품질:")
        print(f"  평균 예측 평점: {np.mean(all_ratings):.3f}")
        print(f"  예측 평점 범위: {min(all_ratings):.3f} ~ {max(all_ratings):.3f}")

    if all_bonuses:
        print(f"  평균 개인화 보너스: {np.mean(all_bonuses):.3f}")
        print(f"  개인화 보너스 범위: {min(all_bonuses):.3f} ~ {max(all_bonuses):.3f}")

# **결과 저장 및 로드 함수**
def save_and_load_results():
    """
    결과 저장 및 로드 예시
    """
    try:
        # 결과 로드
        result_path = '/content/drive/MyDrive/데사경영학술제/result_data/amazon_recommendation_ablation.pkl'
        saved_results = pd.read_pickle(result_path)

        print("✅ 저장된 결과 로드 성공!")
        print(f"로드된 데이터: {len(saved_results)}명의 사용자")

        return saved_results

    except FileNotFoundError:
        print("❌ 저장된 결과 파일을 찾을 수 없습니다.")
        print("추천 시스템을 먼저 실행해주세요.")
        return None
    except Exception as e:
        print(f"❌ 결과 로드 실패: {e}")
        return None

# **메인 결과 확인 코드**
def main_result_check():
    """
    메인 결과 확인 함수
    """
    print("=== 최종 추천 시스템 결과 확인 시작 ===\n")

    # 1. 결과 로드
    final_df = save_and_load_results()

    if final_df is not None:
        # 2. 통계 분석
        analyze_final_results(final_df)

        print("\n" + "="*60)

        # 3. 상세 결과 출력 (처음 3명만)
        print("📋 상세 결과 샘플 (처음 3명):")
        sample_df = final_df.head(3)
        print_final_recommendations(sample_df)

        # 4. 전체 결과 출력 여부 확인
        if len(final_df) > 3:
            print(f"📝 전체 {len(final_df)}명의 결과를 모두 보려면:")
            print("print_final_recommendations(final_df)")
    else:
        print("결과 데이터가 없습니다. 추천 시스템을 먼저 실행해주세요.")

# **실행**
main_result_check()
# Out:
# === 최종 추천 시스템 결과 확인 시작 ===
#
# ✅ 저장된 결과 로드 성공!
# 로드된 데이터: 1697명의 사용자
# === 최종 결과 통계 분석 ===
#
# 📊 기본 통계:
#   총 사용자 수: 1697명
#   프로필 생성 성공: 1697명 (100.0%)
#   추천 생성 성공: 1697명 (100.0%)
#
# 🎯 Feature 분포:
#   Numericals: 618명 (36.4%)
#   Directors: 617명 (36.4%)
#   Cast: 272명 (16.0%)
#   Producers: 86명 (5.1%)
#   TitleEmbedding: 53명 (3.1%)
#   DescriptionEmbedding: 51명 (3.0%)
#
# 📈 성능 지표:
#   평균 신뢰도: 0.121
#   평균 성공률: 65.96%
#   신뢰도 범위: -0.051 ~ 0.640
#   성공률 범위: 30.00% ~ 100.00%
#
# 🎬 추천 품질:
#   평균 예측 평점: 4.654
#   예측 평점 범위: 4.011 ~ 4.792
#   평균 개인화 보너스: 0.027
#   개인화 보너스 범위: 0.000 ~ 0.139
#
# ============================================================
# 📋 상세 결과 샘플 (처음 3명):
# === 총 3명 사용자의 최종 추천 결과 ===
#
# 🎯 사용자 유형 분포:
#   Numericals 중심 사용자: 2명 (66.7%)
#   Cast 중심 사용자: 1명 (33.3%)
#
# --- 사용자 AFZUK3MTBIBEDQOPAK3OATUOUKLA (ID: 0) ---
# 🎯 주요 특성: Numericals
# 📊 신뢰도: 0.252
# 📈 성공률: 80.00%
# 📋 분석 기반: 8개 영화
# 📊 Feature 가중치:
#    Directors: 0.185
#    Producers: 0.079
#    Cast: -0.003
#    Numericals: 0.252
#    DescriptionEmbedding: -0.108
#    TitleEmbedding: -0.064
#
# 🎬 추천 영화:
#   1. Duck Dynasty
#      ⭐ 최종 점수: 4.659
#      📊 기본 점수: 4.834
#      🎯 개인화 보너스: 0.062
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.181
#         Producers: 0.078
#         Cast: -0.003
#         Numericals: 0.116
#         DescriptionEmbedding: -0.106
#         TitleEmbedding: -0.063
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   2. Suits
#      ⭐ 최종 점수: 4.621
#      📊 기본 점수: 4.799
#      🎯 개인화 보너스: 0.056
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.177
#         Producers: 0.048
#         Cast: -0.003
#         Numericals: 0.114
#         DescriptionEmbedding: -0.103
#         TitleEmbedding: -0.062
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Trapped [English Subtitled]
#      ⭐ 최종 점수: 4.620
#      📊 기본 점수: 4.796
#      🎯 개인화 보너스: 0.058
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B071WB7XGG
#      🎭 감독: Börkur Sigþórsson, Baltasar Kormákur, Óskar Thór Axelsson, Baldvin Zophoníasson, Katrín Björgvinsdóttir, Ugla Hauksdóttir
#      🎬 출연진: Ólafur Darri Ólafsson, Ilmur Krist Jánsdóttir, Ingvar Eggert Sigurðsson, Nína Dögg Filippusdóttir, Baltasar Breki Samper, Björn Hlynur Haraldsson, Bjarne Henriksen
#      📈 Feature 기여도:
#         Directors: 0.166
#         Producers: 0.071
#         Cast: -0.003
#         Numericals: 0.109
#         DescriptionEmbedding: -0.097
#         TitleEmbedding: -0.058
#      🎭 영화 매력도:
#         Directors: 0.900
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.433
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   4. The Sixth Sense
#      ⭐ 최종 점수: 4.596
#      📊 기본 점수: 4.769
#      🎯 개인화 보너스: 0.066
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00X9LNFBI
#      🎭 감독: M. Night Shyamalan
#      🎬 출연진: Bruce Willis, Haley Joel Osment, Toni Collette
#      📈 Feature 기여도:
#         Directors: 0.175
#         Producers: 0.076
#         Cast: -0.003
#         Numericals: 0.148
#         DescriptionEmbedding: -0.103
#         TitleEmbedding: -0.062
#      🎭 영화 매력도:
#         Directors: 0.944
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Love Affair - 1939
#      ⭐ 최종 점수: 4.592
#      📊 기본 점수: 4.768
#      🎯 개인화 보너스: 0.059
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.599999904632568
#      📂 ASIN: B006QF15V6
#      🎭 감독: Moving Picture Archive
#      🎬 출연진: Charles Boyer, Irene Dunne
#      📈 Feature 기여도:
#         Directors: 0.170
#         Producers: 0.073
#         Cast: -0.003
#         Numericals: 0.111
#         DescriptionEmbedding: -0.099
#         TitleEmbedding: -0.059
#      🎭 영화 매력도:
#         Directors: 0.920
#         Producers: 0.920
#         Cast: 0.920
#         Numericals: 0.440
#         DescriptionEmbedding: 0.920
#         TitleEmbedding: 0.920
#
# --------------------------------------------------
#
# --- 사용자 AEYE3LSUHQEX6BWG224MKVXX6XZQ (ID: 1) ---
# 🎯 주요 특성: Cast
# 📊 신뢰도: 0.173
# 📈 성공률: 40.00%
# 📋 분석 기반: 4개 영화
# 📊 Feature 가중치:
#    Directors: 0.041
#    Producers: 0.073
#    Cast: 0.173
#    Numericals: 0.105
#    DescriptionEmbedding: 0.060
#    TitleEmbedding: -0.074
#
# 🎬 추천 영화:
#   1. Night and Day (1946)
#      ⭐ 최종 점수: 4.668
#      📊 기본 점수: 4.843
#      🎯 개인화 보너스: 0.062
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.038
#         Producers: 0.066
#         Cast: 0.156
#         Numericals: 0.059
#         DescriptionEmbedding: 0.054
#         TitleEmbedding: -0.066
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   2. Suits
#      ⭐ 최종 점수: 4.664
#      📊 기본 점수: 4.841
#      🎯 개인화 보너스: 0.059
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.040
#         Producers: 0.044
#         Cast: 0.166
#         Numericals: 0.047
#         DescriptionEmbedding: 0.058
#         TitleEmbedding: -0.071
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. The Golden Girls
#      ⭐ 최종 점수: 4.632
#      📊 기본 점수: 4.808
#      🎯 개인화 보너스: 0.060
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00J1ZWX0K
#      🎭 감독: Terry Hughes, Lex Passaris, Matthew Diamond, Jim Drake, Peter D. Beyt, Paul Bogart, Jay Sandrich, Jack Shea, Gary Shimokawa, David Steinberg
#      🎬 출연진: Bea Arthur, Betty White, Rue McClanahan, Estelle Getty, Herb Edelman, Harold Gould, Sid Melton, Bill Dana, Bear the Dog, Meg Wyllie
#      📈 Feature 기여도:
#         Directors: 0.041
#         Producers: 0.044
#         Cast: 0.170
#         Numericals: 0.048
#         DescriptionEmbedding: 0.059
#         TitleEmbedding: -0.072
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.600
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   4. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.628
#      📊 기본 점수: 4.803
#      🎯 개인화 보너스: 0.063
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B007K0PIY6
#      🎭 감독: Chuck Bowman, Gwen Arner, James Keach, Jeremy Kagan, Jerome R. London, Jerry London, Reza Badiyi, Richard Heffron, Victoria Hochberg
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.040
#         Producers: 0.070
#         Cast: 0.166
#         Numericals: 0.047
#         DescriptionEmbedding: 0.058
#         TitleEmbedding: -0.071
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Khartoum
#      ⭐ 최종 점수: 4.609
#      📊 기본 점수: 4.783
#      🎯 개인화 보너스: 0.063
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.599999904632568
#      📂 ASIN: B00HVMMQR0
#      🎭 감독: Basil Dearden
#      🎬 출연진: Ralph Richardson, Charlton Heston, Richard Johnson, Laurence Olivier
#      📈 Feature 기여도:
#         Directors: 0.038
#         Producers: 0.067
#         Cast: 0.159
#         Numericals: 0.060
#         DescriptionEmbedding: 0.055
#         TitleEmbedding: -0.068
#      🎭 영화 매력도:
#         Directors: 0.920
#         Producers: 0.920
#         Cast: 0.920
#         Numericals: 0.573
#         DescriptionEmbedding: 0.920
#         TitleEmbedding: 0.920
#
# --------------------------------------------------
#
# --- 사용자 AHU2GG5RF6YAEWUFNLH3QH5RHDNQ (ID: 2) ---
# 🎯 주요 특성: Numericals
# 📊 신뢰도: 0.131
# 📈 성공률: 100.00%
# 📋 분석 기반: 10개 영화
# 📊 Feature 가중치:
#    Directors: -0.035
#    Producers: -0.005
#    Cast: -0.051
#    Numericals: 0.131
#    DescriptionEmbedding: -0.065
#    TitleEmbedding: -0.048
#
# 🎬 추천 영화:
#   1. Suits
#      ⭐ 최종 점수: 4.687
#      📊 기본 점수: 4.883
#      🎯 개인화 보너스: 0.010
#      🏆 추천 이유: Numericals 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: -0.033
#         Producers: -0.003
#         Cast: -0.049
#         Numericals: 0.059
#         DescriptionEmbedding: -0.063
#         TitleEmbedding: -0.046
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.667
#      📊 기본 점수: 4.863
#      🎯 개인화 보너스: 0.010
#      🏆 추천 이유: Numericals 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: -0.033
#         Producers: -0.005
#         Cast: -0.049
#         Numericals: 0.059
#         DescriptionEmbedding: -0.063
#         TitleEmbedding: -0.046
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Night and Day (1946)
#      ⭐ 최종 점수: 4.666
#      📊 기본 점수: 4.861
#      🎯 개인화 보너스: 0.012
#      🏆 추천 이유: Numericals 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: -0.032
#         Producers: -0.005
#         Cast: -0.046
#         Numericals: 0.074
#         DescriptionEmbedding: -0.059
#         TitleEmbedding: -0.043
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   4. Sense And Sensibility
#      ⭐ 최종 점수: 4.648
#      📊 기본 점수: 4.843
#      🎯 개인화 보너스: 0.013
#      🏆 추천 이유: Numericals 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0019TYQ38
#      🎭 감독: Ang Lee
#      🎬 출연진: Emma Thompson, Kate Winslet, James Fleet
#      📈 Feature 기여도:
#         Directors: -0.033
#         Producers: -0.005
#         Cast: -0.049
#         Numericals: 0.077
#         DescriptionEmbedding: -0.063
#         TitleEmbedding: -0.046
#      🎭 영화 매력도:
#         Directors: 0.945
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Justified
#      ⭐ 최종 점수: 4.638
#      📊 기본 점수: 4.834
#      🎯 개인화 보너스: 0.010
#      🏆 추천 이유: Numericals 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00APE1NZW
#      🎭 감독: Adam Arkin, Jon Avnet, Peter Werner, Michael Dinner, John Dahl, Bill Johnson, Michael W. Watkins, Gwyneth Horder-Payton, Don Kurt, Dean Parisot
#      🎬 출연진: Timothy Olyphant, Nick Searcy, Joelle Carter, Jacob Pitts, Erica Tazel, Walton Goggins, Natalie Zea, Jere Burns, David Meunier, Jonathan Kowalsky
#      📈 Feature 기여도:
#         Directors: -0.034
#         Producers: -0.005
#         Cast: -0.050
#         Numericals: 0.060
#         DescriptionEmbedding: -0.064
#         TitleEmbedding: -0.047
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
# --------------------------------------------------
#
# 📝 전체 1697명의 결과를 모두 보려면:
# print_final_recommendations(final_df)

# %%
print_final_recommendations(final_df)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Flying Tigers
#      ⭐ 최종 점수: 4.657
#      📊 기본 점수: 4.850
#      🎯 개인화 보너스: 0.016
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.699999809265137
#      📂 ASIN: B07VBBHR7D
#      🎭 감독: David Miller
#      🎬 출연진: John Wayne, Join Carroll, Anna Lee
#      📈 Feature 기여도:
#         Directors: -0.064
#         Producers: -0.023
#         Cast: 0.098
#         Numericals: -0.031
#         DescriptionEmbedding: -0.030
#         TitleEmbedding: -0.051
#      🎭 영화 매력도:
#         Directors: 0.940
#         Producers: 0.940
#         Cast: 0.940
#         Numericals: 0.580
#         DescriptionEmbedding: 0.940
#         TitleEmbedding: 0.940
#
#   3. Duck Dynasty
#      ⭐ 최종 점수: 4.652
#      📊 기본 점수: 4.845
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: -0.066
#         Producers: -0.024
#         Cast: 0.102
#         Numericals: -0.025
#         DescriptionEmbedding: -0.031
#         TitleEmbedding: -0.053
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   4. Curious George
#      ⭐ 최종 점수: 4.639
#      📊 기본 점수: 4.833
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B000KHM63M
#      🎭 감독: Matthew O'Callaghan
#      🎬 출연진: Will Ferrell, Drew Barrymore, Frank Welker, David Cross, Eugene Levy, Dick Van Dyke
#      📈 Feature 기여도:
#         Directors: -0.065
#         Producers: -0.023
#         Cast: 0.100
#         Numericals: -0.024
#         DescriptionEmbedding: -0.031
#         TitleEmbedding: -0.052
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.639
#      📊 기본 점수: 4.832
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0126KVXY8
#      🎭 감독: Chuck Bowman, James Keach, Jerry London, Gwen Arner, Alan J. Levi, Terrence O'Hara, Jerry Jameson, Bethany Rooney, Victor Lobl, Daniel Attias
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: -0.065
#         Producers: -0.023
#         Cast: 0.100
#         Numericals: -0.024
#         DescriptionEmbedding: -0.031
#         TitleEmbedding: -0.052
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AHXRF6XBRDFS2VVLJT45AOSJWGQA (ID: 1929) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.098
# 📈 성공률: 70.00%
# 📋 분석 기반: 7개 영화
# 📊 Feature 가중치:
#    Directors: 0.098
#    Producers: 0.005
#    Cast: 0.061
#    Numericals: 0.088
#    DescriptionEmbedding: -0.052
#    TitleEmbedding: -0.012
#
# 🎬 추천 영화:
#   1. Duck Dynasty
#      ⭐ 최종 점수: 4.692
#      📊 기본 점수: 4.878
#      🎯 개인화 보너스: 0.034
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.096
#         Producers: 0.005
#         Cast: 0.060
#         Numericals: 0.041
#         DescriptionEmbedding: -0.051
#         TitleEmbedding: -0.012
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   2. Night and Day (1946)
#      ⭐ 최종 점수: 4.667
#      📊 기본 점수: 4.854
#      🎯 개인화 보너스: 0.034
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.091
#         Producers: 0.005
#         Cast: 0.055
#         Numericals: 0.050
#         DescriptionEmbedding: -0.046
#         TitleEmbedding: -0.011
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.642
#      📊 기본 점수: 4.829
#      🎯 개인화 보너스: 0.033
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: 0.094
#         Producers: 0.005
#         Cast: 0.059
#         Numericals: 0.040
#         DescriptionEmbedding: -0.050
#         TitleEmbedding: -0.012
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Detective Anna
#      ⭐ 최종 점수: 4.628
#      📊 기본 점수: 4.816
#      🎯 개인화 보너스: 0.031
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B07957YPDW
#      🎭 감독: Feliks Gerchikov, Eugeniy Semenov, Artur Rumynskiy
#      🎬 출연진: Aleksandra Nikiforova, Dmitriy Frid, Sergei Druzyak, Irina Sidorova, Andrey Ryklin
#      📈 Feature 기여도:
#         Directors: 0.089
#         Producers: 0.005
#         Cast: 0.055
#         Numericals: 0.038
#         DescriptionEmbedding: -0.046
#         TitleEmbedding: -0.011
#      🎭 영화 매력도:
#         Directors: 0.900
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.433
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   5. Downton Abbey
#      ⭐ 최종 점수: 4.624
#      📊 기본 점수: 4.811
#      🎯 개인화 보너스: 0.034
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B009ZQ8FQG
#      🎭 감독: Brian Percival, Andy Goddard, Jeremy Webb, David Evans
#      🎬 출연진: Huge Bonneville, Michelle Dockery, Maggie Smith, Jim Carter, Robert James-Collier, Dan Stevens, Elizabeth McGovern
#      📈 Feature 기여도:
#         Directors: 0.096
#         Producers: 0.005
#         Cast: 0.060
#         Numericals: 0.041
#         DescriptionEmbedding: -0.051
#         TitleEmbedding: -0.012
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
# --------------------------------------------------
#
# --- 사용자 AEAFOXNZ2PHZYTFI32UE6OPDMTJA (ID: 1930) ---
# 🎯 주요 특성: TitleEmbedding
# 📊 신뢰도: -0.041
# 📈 성공률: 100.00%
# 📋 분석 기반: 10개 영화
# 📊 Feature 가중치:
#    Directors: -0.056
#    Producers: -0.124
#    Cast: -0.048
#    Numericals: -0.228
#    DescriptionEmbedding: -0.136
#    TitleEmbedding: -0.041
#
# 🎬 추천 영화:
#   1. Duck Dynasty
#      ⭐ 최종 점수: 4.585
#      📊 기본 점수: 4.785
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: -0.055
#         Producers: -0.122
#         Cast: -0.047
#         Numericals: -0.105
#         DescriptionEmbedding: -0.133
#         TitleEmbedding: -0.040
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   2. Night and Day (1946)
#      ⭐ 최종 점수: 4.580
#      📊 기본 점수: 4.780
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: -0.052
#         Producers: -0.112
#         Cast: -0.043
#         Numericals: -0.129
#         DescriptionEmbedding: -0.122
#         TitleEmbedding: -0.037
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Mr. Deeds Goes To Town
#      ⭐ 최종 점수: 4.562
#      📊 기본 점수: 4.762
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00RNV536K
#      🎭 감독: Frank Capra
#      🎬 출연진: Gary Cooper, Jean Arthur, George Bancroft, Lionel Stander, Douglass Dumbrille, Raymond Walburn, H.B. Warner
#      📈 Feature 기여도:
#         Directors: -0.052
#         Producers: -0.119
#         Cast: -0.046
#         Numericals: -0.134
#         DescriptionEmbedding: -0.130
#         TitleEmbedding: -0.039
#      🎭 영화 매력도:
#         Directors: 0.915
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Imitation of Life (1934)
#      ⭐ 최종 점수: 4.561
#      📊 기본 점수: 4.761
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B002GRQ4NW
#      🎭 감독: John M. Stahl
#      🎬 출연진: Louise Beavers, Claudette Colbert, Ned Sparks, Warren William, Rochelle Hudson
#      📈 Feature 기여도:
#         Directors: -0.054
#         Producers: -0.075
#         Cast: -0.046
#         Numericals: -0.134
#         DescriptionEmbedding: -0.130
#         TitleEmbedding: -0.039
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.560
#      📊 기본 점수: 4.760
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: -0.054
#         Producers: -0.119
#         Cast: -0.046
#         Numericals: -0.103
#         DescriptionEmbedding: -0.130
#         TitleEmbedding: -0.039
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AE7RGUWOQBLV626XPLXOBSU2ESRA (ID: 1931) ---
# 🎯 주요 특성: DescriptionEmbedding
# 📊 신뢰도: 0.095
# 📈 성공률: 60.00%
# 📋 분석 기반: 6개 영화
# 📊 Feature 가중치:
#    Directors: 0.060
#    Producers: -0.017
#    Cast: -0.074
#    Numericals: -0.244
#    DescriptionEmbedding: 0.095
#    TitleEmbedding: -0.070
#
# 🎬 추천 영화:
#   1. To Kill a Mockingbird
#      ⭐ 최종 점수: 4.667
#      📊 기본 점수: 4.857
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: DescriptionEmbedding 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B000I9VOO4
#      🎭 감독: Robert Mulligan
#      🎬 출연진: Gregory Peck, Mary Badham, Phillip Alford, Robert Duvall
#      📈 Feature 기여도:
#         Directors: 0.059
#         Producers: -0.017
#         Cast: -0.072
#         Numericals: -0.145
#         DescriptionEmbedding: 0.093
#         TitleEmbedding: -0.069
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.593
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   2. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.664
#      📊 기본 점수: 4.854
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: DescriptionEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: 0.058
#         Producers: -0.017
#         Cast: -0.071
#         Numericals: -0.110
#         DescriptionEmbedding: 0.092
#         TitleEmbedding: -0.067
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Flying Tigers
#      ⭐ 최종 점수: 4.656
#      📊 기본 점수: 4.846
#      🎯 개인화 보너스: 0.024
#      🏆 추천 이유: DescriptionEmbedding 특성 기반
#      ⭐ 평균 별점: 4.699999809265137
#      📂 ASIN: B07VBBHR7D
#      🎭 감독: David Miller
#      🎬 출연진: John Wayne, Join Carroll, Anna Lee
#      📈 Feature 기여도:
#         Directors: 0.056
#         Producers: -0.016
#         Cast: -0.069
#         Numericals: -0.141
#         DescriptionEmbedding: 0.090
#         TitleEmbedding: -0.066
#      🎭 영화 매력도:
#         Directors: 0.940
#         Producers: 0.940
#         Cast: 0.940
#         Numericals: 0.580
#         DescriptionEmbedding: 0.940
#         TitleEmbedding: 0.940
#
#   4. Suits
#      ⭐ 최종 점수: 4.656
#      📊 기본 점수: 4.846
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: DescriptionEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.058
#         Producers: -0.010
#         Cast: -0.071
#         Numericals: -0.110
#         DescriptionEmbedding: 0.092
#         TitleEmbedding: -0.067
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.633
#      📊 기본 점수: 4.823
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: DescriptionEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0126KVXY8
#      🎭 감독: Chuck Bowman, James Keach, Jerry London, Gwen Arner, Alan J. Levi, Terrence O'Hara, Jerry Jameson, Bethany Rooney, Victor Lobl, Daniel Attias
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.058
#         Producers: -0.017
#         Cast: -0.071
#         Numericals: -0.110
#         DescriptionEmbedding: 0.092
#         TitleEmbedding: -0.067
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AEZ54227DKYR6DHIQ5XW2ZYJOEKA (ID: 1932) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.070
# 📈 성공률: 50.00%
# 📋 분석 기반: 5개 영화
# 📊 Feature 가중치:
#    Directors: 0.070
#    Producers: -0.248
#    Cast: -0.125
#    Numericals: -0.258
#    DescriptionEmbedding: -0.273
#    TitleEmbedding: -0.153
#
# 🎬 추천 영화:
#   1. Suits
#      ⭐ 최종 점수: 4.638
#      📊 기본 점수: 4.834
#      🎯 개인화 보너스: 0.011
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.067
#         Producers: -0.149
#         Cast: -0.120
#         Numericals: -0.117
#         DescriptionEmbedding: -0.262
#         TitleEmbedding: -0.146
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Night and Day (1946)
#      ⭐ 최종 점수: 4.631
#      📊 기본 점수: 4.826
#      🎯 개인화 보너스: 0.011
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.065
#         Producers: -0.223
#         Cast: -0.113
#         Numericals: -0.146
#         DescriptionEmbedding: -0.245
#         TitleEmbedding: -0.137
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.589
#      📊 기본 점수: 4.785
#      🎯 개인화 보너스: 0.011
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0126KVXY8
#      🎭 감독: Chuck Bowman, James Keach, Jerry London, Gwen Arner, Alan J. Levi, Terrence O'Hara, Jerry Jameson, Bethany Rooney, Victor Lobl, Daniel Attias
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.067
#         Producers: -0.237
#         Cast: -0.120
#         Numericals: -0.117
#         DescriptionEmbedding: -0.262
#         TitleEmbedding: -0.146
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.584
#      📊 기본 점수: 4.779
#      🎯 개인화 보너스: 0.011
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B007K0PIY6
#      🎭 감독: Chuck Bowman, Gwen Arner, James Keach, Jeremy Kagan, Jerome R. London, Jerry London, Reza Badiyi, Richard Heffron, Victoria Hochberg
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.067
#         Producers: -0.237
#         Cast: -0.120
#         Numericals: -0.117
#         DescriptionEmbedding: -0.262
#         TitleEmbedding: -0.146
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Imitation of Life (1934)
#      ⭐ 최종 점수: 4.578
#      📊 기본 점수: 4.774
#      🎯 개인화 보너스: 0.011
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B002GRQ4NW
#      🎭 감독: John M. Stahl
#      🎬 출연진: Louise Beavers, Claudette Colbert, Ned Sparks, Warren William, Rochelle Hudson
#      📈 Feature 기여도:
#         Directors: 0.067
#         Producers: -0.149
#         Cast: -0.120
#         Numericals: -0.151
#         DescriptionEmbedding: -0.262
#         TitleEmbedding: -0.146
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AFPZHVVD7S7OMI6PQARE7UZSFXGA (ID: 1933) ---
# 🎯 주요 특성: Cast
# 📊 신뢰도: 0.009
# 📈 성공률: 30.00%
# 📋 분석 기반: 3개 영화
# 📊 Feature 가중치:
#    Directors: 0.007
#    Producers: -0.073
#    Cast: 0.009
#    Numericals: -0.169
#    DescriptionEmbedding: -0.204
#    TitleEmbedding: -0.164
#
# 🎬 추천 영화:
#   1. Night and Day (1946)
#      ⭐ 최종 점수: 4.702
#      📊 기본 점수: 4.901
#      🎯 개인화 보너스: 0.002
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.007
#         Producers: -0.066
#         Cast: 0.008
#         Numericals: -0.096
#         DescriptionEmbedding: -0.183
#         TitleEmbedding: -0.148
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   2. Suits
#      ⭐ 최종 점수: 4.675
#      📊 기본 점수: 4.874
#      🎯 개인화 보너스: 0.003
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.007
#         Producers: -0.044
#         Cast: 0.009
#         Numericals: -0.077
#         DescriptionEmbedding: -0.196
#         TitleEmbedding: -0.158
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Duck Dynasty
#      ⭐ 최종 점수: 4.670
#      📊 기본 점수: 4.869
#      🎯 개인화 보너스: 0.003
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.007
#         Producers: -0.071
#         Cast: 0.009
#         Numericals: -0.078
#         DescriptionEmbedding: -0.200
#         TitleEmbedding: -0.161
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   4. Mr. Deeds Goes To Town
#      ⭐ 최종 점수: 4.652
#      📊 기본 점수: 4.851
#      🎯 개인화 보너스: 0.003
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00RNV536K
#      🎭 감독: Frank Capra
#      🎬 출연진: Gary Cooper, Jean Arthur, George Bancroft, Lionel Stander, Douglass Dumbrille, Raymond Walburn, H.B. Warner
#      📈 Feature 기여도:
#         Directors: 0.007
#         Producers: -0.070
#         Cast: 0.009
#         Numericals: -0.099
#         DescriptionEmbedding: -0.196
#         TitleEmbedding: -0.158
#      🎭 영화 매력도:
#         Directors: 0.915
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.638
#      📊 기본 점수: 4.837
#      🎯 개인화 보너스: 0.003
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0126KVXY8
#      🎭 감독: Chuck Bowman, James Keach, Jerry London, Gwen Arner, Alan J. Levi, Terrence O'Hara, Jerry Jameson, Bethany Rooney, Victor Lobl, Daniel Attias
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.007
#         Producers: -0.070
#         Cast: 0.009
#         Numericals: -0.077
#         DescriptionEmbedding: -0.196
#         TitleEmbedding: -0.158
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AFESBY72PXPKEDLWHTVIPHJLTCEA (ID: 1935) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.105
# 📈 성공률: 50.00%
# 📋 분석 기반: 5개 영화
# 📊 Feature 가중치:
#    Directors: 0.105
#    Producers: -0.136
#    Cast: -0.068
#    Numericals: -0.219
#    DescriptionEmbedding: -0.215
#    TitleEmbedding: -0.120
#
# 🎬 추천 영화:
#   1. Duck Dynasty
#      ⭐ 최종 점수: 4.728
#      📊 기본 점수: 4.922
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.103
#         Producers: -0.133
#         Cast: -0.067
#         Numericals: -0.101
#         DescriptionEmbedding: -0.211
#         TitleEmbedding: -0.118
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   2. Night and Day (1946)
#      ⭐ 최종 점수: 4.720
#      📊 기본 점수: 4.914
#      🎯 개인화 보너스: 0.016
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.097
#         Producers: -0.123
#         Cast: -0.062
#         Numericals: -0.124
#         DescriptionEmbedding: -0.193
#         TitleEmbedding: -0.108
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Suits
#      ⭐ 최종 점수: 4.715
#      📊 기본 점수: 4.909
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.101
#         Producers: -0.082
#         Cast: -0.066
#         Numericals: -0.099
#         DescriptionEmbedding: -0.206
#         TitleEmbedding: -0.115
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.702
#      📊 기본 점수: 4.896
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B007K0PIY6
#      🎭 감독: Chuck Bowman, Gwen Arner, James Keach, Jeremy Kagan, Jerome R. London, Jerry London, Reza Badiyi, Richard Heffron, Victoria Hochberg
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.101
#         Producers: -0.130
#         Cast: -0.066
#         Numericals: -0.099
#         DescriptionEmbedding: -0.206
#         TitleEmbedding: -0.115
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.701
#      📊 기본 점수: 4.895
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0126KVXY8
#      🎭 감독: Chuck Bowman, James Keach, Jerry London, Gwen Arner, Alan J. Levi, Terrence O'Hara, Jerry Jameson, Bethany Rooney, Victor Lobl, Daniel Attias
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.101
#         Producers: -0.130
#         Cast: -0.066
#         Numericals: -0.099
#         DescriptionEmbedding: -0.206
#         TitleEmbedding: -0.115
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AFKLF5KLSDK6S6S24GAQETKBB5UA (ID: 1937) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.102
# 📈 성공률: 50.00%
# 📋 분석 기반: 5개 영화
# 📊 Feature 가중치:
#    Directors: 0.102
#    Producers: -0.280
#    Cast: -0.008
#    Numericals: -0.076
#    DescriptionEmbedding: -0.063
#    TitleEmbedding: -0.056
#
# 🎬 추천 영화:
#   1. Suits
#      ⭐ 최종 점수: 4.710
#      📊 기본 점수: 4.903
#      🎯 개인화 보너스: 0.016
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.098
#         Producers: -0.168
#         Cast: -0.007
#         Numericals: -0.034
#         DescriptionEmbedding: -0.060
#         TitleEmbedding: -0.054
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Night and Day (1946)
#      ⭐ 최종 점수: 4.681
#      📊 기본 점수: 4.875
#      🎯 개인화 보너스: 0.016
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.095
#         Producers: -0.252
#         Cast: -0.007
#         Numericals: -0.043
#         DescriptionEmbedding: -0.057
#         TitleEmbedding: -0.051
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Duck Dynasty
#      ⭐ 최종 점수: 4.679
#      📊 기본 점수: 4.872
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.100
#         Producers: -0.274
#         Cast: -0.007
#         Numericals: -0.035
#         DescriptionEmbedding: -0.062
#         TitleEmbedding: -0.055
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   4. To Kill a Mockingbird
#      ⭐ 최종 점수: 4.668
#      📊 기본 점수: 4.862
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B000I9VOO4
#      🎭 감독: Robert Mulligan
#      🎬 출연진: Gregory Peck, Mary Badham, Phillip Alford, Robert Duvall
#      📈 Feature 기여도:
#         Directors: 0.100
#         Producers: -0.274
#         Cast: -0.007
#         Numericals: -0.045
#         DescriptionEmbedding: -0.062
#         TitleEmbedding: -0.055
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.593
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   5. Vera
#      ⭐ 최종 점수: 4.647
#      📊 기본 점수: 4.841
#      🎯 개인화 보너스: 0.016
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00OH8SGFC
#      🎭 감독: Thaddeus O'Sullivan, Daikin Marsh, Will Sinclair, David Richards
#      🎬 출연진: Brenda Blethyn, David Leon
#      📈 Feature 기여도:
#         Directors: 0.098
#         Producers: -0.269
#         Cast: -0.007
#         Numericals: -0.034
#         DescriptionEmbedding: -0.060
#         TitleEmbedding: -0.054
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.936
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AGN327XLYAGP3PABJTK2BO5WMHPA (ID: 1938) ---
# 🎯 주요 특성: Numericals
# 📊 신뢰도: 0.104
# 📈 성공률: 70.00%
# 📋 분석 기반: 7개 영화
# 📊 Feature 가중치:
#    Directors: 0.037
#    Producers: -0.057
#    Cast: 0.069
#    Numericals: 0.104
#    DescriptionEmbedding: -0.137
#    TitleEmbedding: -0.007
#
# 🎬 추천 영화:
#   1. Duck Dynasty
#      ⭐ 최종 점수: 4.562
#      📊 기본 점수: 4.751
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.037
#         Producers: -0.056
#         Cast: 0.067
#         Numericals: 0.048
#         DescriptionEmbedding: -0.134
#         TitleEmbedding: -0.007
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   2. Imitation of Life (1934)
#      ⭐ 최종 점수: 4.515
#      📊 기본 점수: 4.704
#      🎯 개인화 보너스: 0.027
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B002GRQ4NW
#      🎭 감독: John M. Stahl
#      🎬 출연진: Louise Beavers, Claudette Colbert, Ned Sparks, Warren William, Rochelle Hudson
#      📈 Feature 기여도:
#         Directors: 0.036
#         Producers: -0.034
#         Cast: 0.066
#         Numericals: 0.061
#         DescriptionEmbedding: -0.131
#         TitleEmbedding: -0.007
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Suits
#      ⭐ 최종 점수: 4.505
#      📊 기본 점수: 4.695
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.036
#         Producers: -0.034
#         Cast: 0.066
#         Numericals: 0.047
#         DescriptionEmbedding: -0.131
#         TitleEmbedding: -0.007
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Night and Day (1946)
#      ⭐ 최종 점수: 4.500
#      📊 기본 점수: 4.689
#      🎯 개인화 보너스: 0.026
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.035
#         Producers: -0.052
#         Cast: 0.062
#         Numericals: 0.059
#         DescriptionEmbedding: -0.123
#         TitleEmbedding: -0.006
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   5. Khartoum
#      ⭐ 최종 점수: 4.499
#      📊 기본 점수: 4.689
#      🎯 개인화 보너스: 0.026
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.599999904632568
#      📂 ASIN: B00HVMMQR0
#      🎭 감독: Basil Dearden
#      🎬 출연진: Ralph Richardson, Charlton Heston, Richard Johnson, Laurence Olivier
#      📈 Feature 기여도:
#         Directors: 0.034
#         Producers: -0.053
#         Cast: 0.063
#         Numericals: 0.060
#         DescriptionEmbedding: -0.126
#         TitleEmbedding: -0.006
#      🎭 영화 매력도:
#         Directors: 0.920
#         Producers: 0.920
#         Cast: 0.920
#         Numericals: 0.573
#         DescriptionEmbedding: 0.920
#         TitleEmbedding: 0.920
#
# --------------------------------------------------
#
# --- 사용자 AFMQON4B5PT6SRIGRT556OGHALCQ (ID: 1939) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.021
# 📈 성공률: 30.00%
# 📋 분석 기반: 3개 영화
# 📊 Feature 가중치:
#    Directors: 0.021
#    Producers: -0.011
#    Cast: -0.103
#    Numericals: -0.048
#    DescriptionEmbedding: 0.011
#    TitleEmbedding: -0.123
#
# 🎬 추천 영화:
#   1. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.629
#      📊 기본 점수: 4.827
#      🎯 개인화 보너스: 0.005
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: 0.020
#         Producers: -0.010
#         Cast: -0.099
#         Numericals: -0.022
#         DescriptionEmbedding: 0.010
#         TitleEmbedding: -0.118
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Imitation of Life (1934)
#      ⭐ 최종 점수: 4.607
#      📊 기본 점수: 4.804
#      🎯 개인화 보너스: 0.005
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B002GRQ4NW
#      🎭 감독: John M. Stahl
#      🎬 출연진: Louise Beavers, Claudette Colbert, Ned Sparks, Warren William, Rochelle Hudson
#      📈 Feature 기여도:
#         Directors: 0.020
#         Producers: -0.007
#         Cast: -0.099
#         Numericals: -0.028
#         DescriptionEmbedding: 0.010
#         TitleEmbedding: -0.118
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Mr. Deeds Goes To Town
#      ⭐ 최종 점수: 4.603
#      📊 기본 점수: 4.801
#      🎯 개인화 보너스: 0.005
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00RNV536K
#      🎭 감독: Frank Capra
#      🎬 출연진: Gary Cooper, Jean Arthur, George Bancroft, Lionel Stander, Douglass Dumbrille, Raymond Walburn, H.B. Warner
#      📈 Feature 기여도:
#         Directors: 0.019
#         Producers: -0.010
#         Cast: -0.099
#         Numericals: -0.028
#         DescriptionEmbedding: 0.010
#         TitleEmbedding: -0.118
#      🎭 영화 매력도:
#         Directors: 0.915
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Double Indemnity
#      ⭐ 최종 점수: 4.588
#      📊 기본 점수: 4.786
#      🎯 개인화 보너스: 0.005
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.699999809265137
#      📂 ASIN: B009CGADEQ
#      🎭 감독: Billy Wilder
#      🎬 출연진: Fred MacMurray, Barbara Stanwyck, EdwardG. Robinson
#      📈 Feature 기여도:
#         Directors: 0.020
#         Producers: -0.010
#         Cast: -0.096
#         Numericals: -0.028
#         DescriptionEmbedding: 0.010
#         TitleEmbedding: -0.116
#      🎭 영화 매력도:
#         Directors: 0.938
#         Producers: 0.940
#         Cast: 0.940
#         Numericals: 0.580
#         DescriptionEmbedding: 0.940
#         TitleEmbedding: 0.940
#
#   5. The Sixth Sense
#      ⭐ 최종 점수: 4.586
#      📊 기본 점수: 4.784
#      🎯 개인화 보너스: 0.005
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00X9LNFBI
#      🎭 감독: M. Night Shyamalan
#      🎬 출연진: Bruce Willis, Haley Joel Osment, Toni Collette
#      📈 Feature 기여도:
#         Directors: 0.020
#         Producers: -0.010
#         Cast: -0.099
#         Numericals: -0.028
#         DescriptionEmbedding: 0.010
#         TitleEmbedding: -0.118
#      🎭 영화 매력도:
#         Directors: 0.944
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AGHOJOUXTQPIDNI3TTSVKRPOHDVQ (ID: 1940) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.082
# 📈 성공률: 100.00%
# 📋 분석 기반: 10개 영화
# 📊 Feature 가중치:
#    Directors: 0.082
#    Producers: 0.044
#    Cast: -0.057
#    Numericals: -0.086
#    DescriptionEmbedding: -0.162
#    TitleEmbedding: -0.030
#
# 🎬 추천 영화:
#   1. Suits
#      ⭐ 최종 점수: 4.738
#      📊 기본 점수: 4.931
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.078
#         Producers: 0.026
#         Cast: -0.054
#         Numericals: -0.039
#         DescriptionEmbedding: -0.155
#         TitleEmbedding: -0.029
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Duck Dynasty
#      ⭐ 최종 점수: 4.728
#      📊 기본 점수: 4.920
#      🎯 개인화 보너스: 0.020
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.080
#         Producers: 0.043
#         Cast: -0.055
#         Numericals: -0.039
#         DescriptionEmbedding: -0.158
#         TitleEmbedding: -0.030
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   3. Night and Day (1946)
#      ⭐ 최종 점수: 4.722
#      📊 기본 점수: 4.914
#      🎯 개인화 보너스: 0.019
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.076
#         Producers: 0.039
#         Cast: -0.051
#         Numericals: -0.049
#         DescriptionEmbedding: -0.145
#         TitleEmbedding: -0.027
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   4. Mr. Deeds Goes To Town
#      ⭐ 최종 점수: 4.713
#      📊 기본 점수: 4.905
#      🎯 개인화 보너스: 0.019
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00RNV536K
#      🎭 감독: Frank Capra
#      🎬 출연진: Gary Cooper, Jean Arthur, George Bancroft, Lionel Stander, Douglass Dumbrille, Raymond Walburn, H.B. Warner
#      📈 Feature 기여도:
#         Directors: 0.075
#         Producers: 0.042
#         Cast: -0.054
#         Numericals: -0.050
#         DescriptionEmbedding: -0.155
#         TitleEmbedding: -0.029
#      🎭 영화 매력도:
#         Directors: 0.915
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Dr. Quinn Medicine Woman
#      ⭐ 최종 점수: 4.701
#      📊 기본 점수: 4.893
#      🎯 개인화 보너스: 0.020
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0126KVXY8
#      🎭 감독: Chuck Bowman, James Keach, Jerry London, Gwen Arner, Alan J. Levi, Terrence O'Hara, Jerry Jameson, Bethany Rooney, Victor Lobl, Daniel Attias
#      🎬 출연진: Jane Seymour, Joe Lando, Chad Allen, Erika Flores, Barbara Babcock, Orson Bean, Shawn Toovey
#      📈 Feature 기여도:
#         Directors: 0.079
#         Producers: 0.042
#         Cast: -0.054
#         Numericals: -0.039
#         DescriptionEmbedding: -0.155
#         TitleEmbedding: -0.029
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.957
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AE23KEBSB2AOI7CMEGLKGSUELMOQ (ID: 1941) ---
# 🎯 주요 특성: TitleEmbedding
# 📊 신뢰도: 0.065
# 📈 성공률: 40.00%
# 📋 분석 기반: 4개 영화
# 📊 Feature 가중치:
#    Directors: 0.018
#    Producers: 0.008
#    Cast: 0.019
#    Numericals: -0.081
#    DescriptionEmbedding: -0.103
#    TitleEmbedding: 0.065
#
# 🎬 추천 영화:
#   1. Night and Day (1946)
#      ⭐ 최종 점수: 4.751
#      📊 기본 점수: 4.945
#      🎯 개인화 보너스: 0.016
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.016
#         Producers: 0.007
#         Cast: 0.017
#         Numericals: -0.046
#         DescriptionEmbedding: -0.093
#         TitleEmbedding: 0.059
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   2. Suits
#      ⭐ 최종 점수: 4.743
#      📊 기본 점수: 4.936
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.017
#         Producers: 0.005
#         Cast: 0.018
#         Numericals: -0.037
#         DescriptionEmbedding: -0.099
#         TitleEmbedding: 0.062
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. Khartoum
#      ⭐ 최종 점수: 4.714
#      📊 기본 점수: 4.908
#      🎯 개인화 보너스: 0.017
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.599999904632568
#      📂 ASIN: B00HVMMQR0
#      🎭 감독: Basil Dearden
#      🎬 출연진: Ralph Richardson, Charlton Heston, Richard Johnson, Laurence Olivier
#      📈 Feature 기여도:
#         Directors: 0.016
#         Producers: 0.007
#         Cast: 0.017
#         Numericals: -0.047
#         DescriptionEmbedding: -0.095
#         TitleEmbedding: 0.060
#      🎭 영화 매력도:
#         Directors: 0.920
#         Producers: 0.920
#         Cast: 0.920
#         Numericals: 0.573
#         DescriptionEmbedding: 0.920
#         TitleEmbedding: 0.920
#
#   4. To Kill a Mockingbird
#      ⭐ 최종 점수: 4.710
#      📊 기본 점수: 4.903
#      🎯 개인화 보너스: 0.018
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B000ID37RM
#      🎭 감독: Robert Mulligan
#      🎬 출연진: Gregory Peck, Mary Badham, Phillip Alford, Robert Duvall
#      📈 Feature 기여도:
#         Directors: 0.017
#         Producers: 0.008
#         Cast: 0.018
#         Numericals: -0.048
#         DescriptionEmbedding: -0.101
#         TitleEmbedding: 0.064
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.593
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   5. Duck Dynasty
#      ⭐ 최종 점수: 4.709
#      📊 기본 점수: 4.902
#      🎯 개인화 보너스: 0.018
#      🏆 추천 이유: TitleEmbedding 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.017
#         Producers: 0.008
#         Cast: 0.018
#         Numericals: -0.037
#         DescriptionEmbedding: -0.101
#         TitleEmbedding: 0.064
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
# --------------------------------------------------
#
# --- 사용자 AHY5ZS2BLXWBSK5W3ABYNED7MO5A (ID: 1942) ---
# 🎯 주요 특성: Producers
# 📊 신뢰도: 0.080
# 📈 성공률: 50.00%
# 📋 분석 기반: 5개 영화
# 📊 Feature 가중치:
#    Directors: -0.145
#    Producers: 0.080
#    Cast: 0.050
#    Numericals: -0.118
#    DescriptionEmbedding: -0.099
#    TitleEmbedding: 0.044
#
# 🎬 추천 영화:
#   1. Mr. Deeds Goes To Town
#      ⭐ 최종 점수: 4.707
#      📊 기본 점수: 4.896
#      🎯 개인화 보너스: 0.028
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00RNV536K
#      🎭 감독: Frank Capra
#      🎬 출연진: Gary Cooper, Jean Arthur, George Bancroft, Lionel Stander, Douglass Dumbrille, Raymond Walburn, H.B. Warner
#      📈 Feature 기여도:
#         Directors: -0.133
#         Producers: 0.077
#         Cast: 0.048
#         Numericals: -0.069
#         DescriptionEmbedding: -0.095
#         TitleEmbedding: 0.042
#      🎭 영화 매력도:
#         Directors: 0.915
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Night and Day (1946)
#      ⭐ 최종 점수: 4.704
#      📊 기본 점수: 4.893
#      🎯 개인화 보너스: 0.026
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: -0.134
#         Producers: 0.072
#         Cast: 0.045
#         Numericals: -0.067
#         DescriptionEmbedding: -0.089
#         TitleEmbedding: 0.039
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Detective Anna
#      ⭐ 최종 점수: 4.668
#      📊 기본 점수: 4.858
#      🎯 개인화 보너스: 0.026
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B07957YPDW
#      🎭 감독: Feliks Gerchikov, Eugeniy Semenov, Artur Rumynskiy
#      🎬 출연진: Aleksandra Nikiforova, Dmitriy Frid, Sergei Druzyak, Irina Sidorova, Andrey Ryklin
#      📈 Feature 기여도:
#         Directors: -0.131
#         Producers: 0.072
#         Cast: 0.045
#         Numericals: -0.051
#         DescriptionEmbedding: -0.089
#         TitleEmbedding: 0.039
#      🎭 영화 매력도:
#         Directors: 0.900
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.433
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   4. Imitation of Life (1934)
#      ⭐ 최종 점수: 4.664
#      📊 기본 점수: 4.855
#      🎯 개인화 보너스: 0.023
#      🏆 추천 이유: Producers 특성 기반
# ...
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. Detective Anna
#      ⭐ 최종 점수: 4.681
#      📊 기본 점수: 4.859
#      🎯 개인화 보너스: 0.054
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B07957YPDW
#      🎭 감독: Feliks Gerchikov, Eugeniy Semenov, Artur Rumynskiy
#      🎬 출연진: Aleksandra Nikiforova, Dmitriy Frid, Sergei Druzyak, Irina Sidorova, Andrey Ryklin
#      📈 Feature 기여도:
#         Directors: 0.062
#         Producers: 0.034
#         Cast: 0.127
#         Numericals: 0.101
#         DescriptionEmbedding: -0.042
#         TitleEmbedding: -0.025
#      🎭 영화 매력도:
#         Directors: 0.900
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.433
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
# --------------------------------------------------
#
# --- 사용자 AG6W2OH3TRYO4JHBLH6MNA35AS3A (ID: 1965) ---
# 🎯 주요 특성: Cast
# 📊 신뢰도: -0.002
# 📈 성공률: 60.00%
# 📋 분석 기반: 6개 영화
# 📊 Feature 가중치:
#    Directors: -0.009
#    Producers: -0.032
#    Cast: -0.002
#    Numericals: -0.084
#    DescriptionEmbedding: -0.120
#    TitleEmbedding: -0.044
#
# 🎬 추천 영화:
#   1. Suits
#      ⭐ 최종 점수: 4.595
#      📊 기본 점수: 4.795
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: -0.009
#         Producers: -0.019
#         Cast: -0.002
#         Numericals: -0.038
#         DescriptionEmbedding: -0.115
#         TitleEmbedding: -0.043
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. The Red Badge of Courage
#      ⭐ 최종 점수: 4.591
#      📊 기본 점수: 4.791
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B001U0CUMK
#      🎭 감독: John Huston
#      🎬 출연진: Audie Murphy, Bill Mauldin, Royal Dano, Douglas Dick, John Dierkes, Arthur Hunnicutt
#      📈 Feature 기여도:
#         Directors: -0.009
#         Producers: -0.029
#         Cast: -0.002
#         Numericals: -0.036
#         DescriptionEmbedding: -0.108
#         TitleEmbedding: -0.040
#      🎭 영화 매력도:
#         Directors: 0.926
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.433
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   3. Imitation of Life (1934)
#      ⭐ 최종 점수: 4.586
#      📊 기본 점수: 4.786
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B002GRQ4NW
#      🎭 감독: John M. Stahl
#      🎬 출연진: Louise Beavers, Claudette Colbert, Ned Sparks, Warren William, Rochelle Hudson
#      📈 Feature 기여도:
#         Directors: -0.009
#         Producers: -0.019
#         Cast: -0.002
#         Numericals: -0.049
#         DescriptionEmbedding: -0.115
#         TitleEmbedding: -0.043
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Double Indemnity
#      ⭐ 최종 점수: 4.570
#      📊 기본 점수: 4.770
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.699999809265137
#      📂 ASIN: B009CGADEQ
#      🎭 감독: Billy Wilder
#      🎬 출연진: Fred MacMurray, Barbara Stanwyck, EdwardG. Robinson
#      📈 Feature 기여도:
#         Directors: -0.009
#         Producers: -0.030
#         Cast: -0.002
#         Numericals: -0.049
#         DescriptionEmbedding: -0.112
#         TitleEmbedding: -0.042
#      🎭 영화 매력도:
#         Directors: 0.938
#         Producers: 0.940
#         Cast: 0.940
#         Numericals: 0.580
#         DescriptionEmbedding: 0.940
#         TitleEmbedding: 0.940
#
#   5. The Unit
#      ⭐ 최종 점수: 4.568
#      📊 기본 점수: 4.768
#      🎯 개인화 보너스: 0.000
#      🏆 추천 이유: Cast 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B0044IAB0S
#      🎭 감독: Steven DePaul, Bill Norton, James Whitmore Jr., Vahan Moosekian, Terrence O'Hara, Steve Gomer, David Mamet, Michael Zinberg, Helen Shaver, Gwyneth Horder-Payton
#      🎬 출연진: Dennis Haysbert, Regina Taylor, Audrey Marie Anderson, Robert Patrick
#      📈 Feature 기여도:
#         Directors: -0.009
#         Producers: -0.019
#         Cast: -0.002
#         Numericals: -0.038
#         DescriptionEmbedding: -0.115
#         TitleEmbedding: -0.043
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AG3H3KND6WA3H2IVDL7RFCR37PYA (ID: 1966) ---
# 🎯 주요 특성: Numericals
# 📊 신뢰도: 0.103
# 📈 성공률: 40.00%
# 📋 분석 기반: 4개 영화
# 📊 Feature 가중치:
#    Directors: 0.080
#    Producers: -0.032
#    Cast: 0.061
#    Numericals: 0.103
#    DescriptionEmbedding: -0.168
#    TitleEmbedding: -0.064
#
# 🎬 추천 영화:
#   1. Suits
#      ⭐ 최종 점수: 4.578
#      📊 기본 점수: 4.766
#      🎯 개인화 보너스: 0.030
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.077
#         Producers: -0.019
#         Cast: 0.059
#         Numericals: 0.047
#         DescriptionEmbedding: -0.162
#         TitleEmbedding: -0.061
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Duck Dynasty
#      ⭐ 최종 점수: 4.544
#      📊 기본 점수: 4.732
#      🎯 개인화 보너스: 0.031
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.079
#         Producers: -0.031
#         Cast: 0.060
#         Numericals: 0.047
#         DescriptionEmbedding: -0.165
#         TitleEmbedding: -0.062
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   3. Night and Day (1946)
#      ⭐ 최종 점수: 4.505
#      📊 기본 점수: 4.692
#      🎯 개인화 보너스: 0.031
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.074
#         Producers: -0.029
#         Cast: 0.055
#         Numericals: 0.058
#         DescriptionEmbedding: -0.152
#         TitleEmbedding: -0.057
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   4. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.503
#      📊 기본 점수: 4.690
#      🎯 개인화 보너스: 0.030
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: 0.077
#         Producers: -0.030
#         Cast: 0.059
#         Numericals: 0.047
#         DescriptionEmbedding: -0.162
#         TitleEmbedding: -0.061
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. To Kill a Mockingbird
#      ⭐ 최종 점수: 4.470
#      📊 기본 점수: 4.657
#      🎯 개인화 보너스: 0.033
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B000I9VOO4
#      🎭 감독: Robert Mulligan
#      🎬 출연진: Gregory Peck, Mary Badham, Phillip Alford, Robert Duvall
#      📈 Feature 기여도:
#         Directors: 0.079
#         Producers: -0.031
#         Cast: 0.060
#         Numericals: 0.061
#         DescriptionEmbedding: -0.165
#         TitleEmbedding: -0.062
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.593
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
# --------------------------------------------------
#
# --- 사용자 AGZLXGDWWGC6YM22XCVAAXXR5HTA (ID: 1967) ---
# 🎯 주요 특성: Producers
# 📊 신뢰도: 0.075
# 📈 성공률: 60.00%
# 📋 분석 기반: 6개 영화
# 📊 Feature 가중치:
#    Directors: 0.044
#    Producers: 0.075
#    Cast: 0.033
#    Numericals: -0.254
#    DescriptionEmbedding: -0.100
#    TitleEmbedding: 0.013
#
# 🎬 추천 영화:
#   1. Night and Day (1946)
#      ⭐ 최종 점수: 4.710
#      📊 기본 점수: 4.900
#      🎯 개인화 보너스: 0.025
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.041
#         Producers: 0.067
#         Cast: 0.029
#         Numericals: -0.144
#         DescriptionEmbedding: -0.090
#         TitleEmbedding: 0.011
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   2. Duck Dynasty
#      ⭐ 최종 점수: 4.682
#      📊 기본 점수: 4.872
#      🎯 개인화 보너스: 0.027
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B00PHNERHC
#      🎭 감독: Jonathan Haug, Hugh Peterson, David Hobbes, Hisham Abed, Mike Odair, Deirdre Gurney, Colin Hargraves, Ryan Powers
#      🎬 출연진: Jase Robertson, Si Robertson, Willie Robertson, Korie Robertson, Kay Robertson, Phil Robertson, Jep Robertson, Missy Robertson, Justin Martin, John Godwin
#      📈 Feature 기여도:
#         Directors: 0.043
#         Producers: 0.073
#         Cast: 0.032
#         Numericals: -0.117
#         DescriptionEmbedding: -0.098
#         TitleEmbedding: 0.013
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.460
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   3. Suits
#      ⭐ 최종 점수: 4.660
#      📊 기본 점수: 4.851
#      🎯 개인화 보너스: 0.022
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.042
#         Producers: 0.045
#         Cast: 0.031
#         Numericals: -0.115
#         DescriptionEmbedding: -0.096
#         TitleEmbedding: 0.012
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   4. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.656
#      📊 기본 점수: 4.845
#      🎯 개인화 보너스: 0.026
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: 0.042
#         Producers: 0.072
#         Cast: 0.031
#         Numericals: -0.115
#         DescriptionEmbedding: -0.096
#         TitleEmbedding: 0.012
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   5. The Sixth Sense
#      ⭐ 최종 점수: 4.640
#      📊 기본 점수: 4.830
#      🎯 개인화 보너스: 0.026
#      🏆 추천 이유: Producers 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00X9LNFBI
#      🎭 감독: M. Night Shyamalan
#      🎬 출연진: Bruce Willis, Haley Joel Osment, Toni Collette
#      📈 Feature 기여도:
#         Directors: 0.041
#         Producers: 0.072
#         Cast: 0.031
#         Numericals: -0.149
#         DescriptionEmbedding: -0.096
#         TitleEmbedding: 0.012
#      🎭 영화 매력도:
#         Directors: 0.944
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.587
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
# --------------------------------------------------
#
# --- 사용자 AFSKEPWGUW7USHA6A3HMU52RUTVA (ID: 1968) ---
# 🎯 주요 특성: Directors
# 📊 신뢰도: 0.640
# 📈 성공률: 40.00%
# 📋 분석 기반: 4개 영화
# 📊 Feature 가중치:
#    Directors: 0.640
#    Producers: -0.014
#    Cast: -0.015
#    Numericals: -0.128
#    DescriptionEmbedding: -0.112
#    TitleEmbedding: -0.016
#
# 🎬 추천 영화:
#   1. Aladdin (Plus Bonus Features)
#      ⭐ 최종 점수: 4.735
#      📊 기본 점수: 4.894
#      🎯 개인화 보너스: 0.102
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00YMIVLMW
#      🎭 감독: Ron Clements, John Musker
#      🎬 출연진: Scott Weinger : Aladdin, Robin Williams : Genie, Linda Larkin : Jasmine, Jonathan Freeman : Jafar
#      📈 Feature 기여도:
#         Directors: 0.615
#         Producers: -0.013
#         Cast: -0.014
#         Numericals: -0.058
#         DescriptionEmbedding: -0.108
#         TitleEmbedding: -0.016
#      🎭 영화 매력도:
#         Directors: 0.960
#         Producers: 0.960
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   2. Suits
#      ⭐ 최종 점수: 4.731
#      📊 기본 점수: 4.891
#      🎯 개인화 보너스: 0.102
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.800000190734863
#      📂 ASIN: B00JJ20QR2
#      🎭 감독: Michael Smith, Anton Cropper, Christopher Misiano, Kevin Bray, Roger Kumble, Silver Tree, John Scott, Cherie Nowlan, Gabriel Macht, Patrick J. Adams
#      🎬 출연진: Gabriel Macht, Patrick J. Adams, Gina Torres, Meghan Markle
#      📈 Feature 기여도:
#         Directors: 0.614
#         Producers: -0.008
#         Cast: -0.014
#         Numericals: -0.058
#         DescriptionEmbedding: -0.108
#         TitleEmbedding: -0.016
#      🎭 영화 매력도:
#         Directors: 0.958
#         Producers: 0.600
#         Cast: 0.960
#         Numericals: 0.453
#         DescriptionEmbedding: 0.960
#         TitleEmbedding: 0.960
#
#   3. To Kill a Mockingbird
#      ⭐ 최종 점수: 4.731
#      📊 기본 점수: 4.889
#      🎯 개인화 보너스: 0.105
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B000ID37RM
#      🎭 감독: Robert Mulligan
#      🎬 출연진: Gregory Peck, Mary Badham, Phillip Alford, Robert Duvall
#      📈 Feature 기여도:
#         Directors: 0.627
#         Producers: -0.013
#         Cast: -0.014
#         Numericals: -0.076
#         DescriptionEmbedding: -0.110
#         TitleEmbedding: -0.016
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.593
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
#   4. Night and Day (1946)
#      ⭐ 최종 점수: 4.720
#      📊 기본 점수: 4.880
#      🎯 개인화 보너스: 0.099
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.5
#      📂 ASIN: B000LJAVA4
#      🎭 감독: Michael Curtiz
#      🎬 출연진: Cary Grant, Alexis Smith, Eve Arden, Jane Wyman
#      📈 Feature 기여도:
#         Directors: 0.592
#         Producers: -0.012
#         Cast: -0.013
#         Numericals: -0.073
#         DescriptionEmbedding: -0.101
#         TitleEmbedding: -0.015
#      🎭 영화 매력도:
#         Directors: 0.925
#         Producers: 0.900
#         Cast: 0.900
#         Numericals: 0.567
#         DescriptionEmbedding: 0.900
#         TitleEmbedding: 0.900
#
#   5. To Kill a Mockingbird
#      ⭐ 최종 점수: 4.715
#      📊 기본 점수: 4.873
#      🎯 개인화 보너스: 0.105
#      🏆 추천 이유: Directors 특성 기반
#      ⭐ 평균 별점: 4.900000095367432
#      📂 ASIN: B000I9VOO4
#      🎭 감독: Robert Mulligan
#      🎬 출연진: Gregory Peck, Mary Badham, Phillip Alford, Robert Duvall
#      📈 Feature 기여도:
#         Directors: 0.627
#         Producers: -0.013
#         Cast: -0.014
#         Numericals: -0.076
#         DescriptionEmbedding: -0.110
#         TitleEmbedding: -0.016
#      🎭 영화 매력도:
#         Directors: 0.980
#         Producers: 0.980
#         Cast: 0.980
#         Numericals: 0.593
#         DescriptionEmbedding: 0.980
#         TitleEmbedding: 0.980
#
# --------------------------------------------------

# %%
# **현재 저장된 결과에서 Feature 분포 분석**

def analyze_user_feature_distribution():
    """
    사용자별 primary feature 분포 분석
    """
    try:
        # 저장된 결과 로드
        result_path = '/content/drive/MyDrive/데사경영학술제/result_data/amazon_recommendation_ablation.pkl'

        # 만약 파일이 없다면 debug_results 사용 (현재 세션의 결과)
        try:
            final_df = pd.read_pickle(result_path)
            print("✅ 저장된 파일에서 결과 로드")
        except:
            # debug_results가 있다면 사용 (현재 세션에서 생성된 결과)
            if 'debug_results' in globals():
                final_df = pd.DataFrame(debug_results)
                print("✅ 현재 세션 결과 사용")
            else:
                print("❌ 결과 데이터를 찾을 수 없습니다.")
                return None

        print(f"총 {len(final_df)}명의 사용자 분석")

        # Feature 분포 계산
        feature_counts = {}
        total_users = len(final_df)

        for _, row in final_df.iterrows():
            user_profile = row.get('user_profile')
            if user_profile and 'primary_feature' in user_profile:
                primary = user_profile['primary_feature']
                feature_counts[primary] = feature_counts.get(primary, 0) + 1

        print("\n🎯 Feature별 사용자 분포:")
        print("=" * 40)

        # 정렬해서 출력
        for feature, count in sorted(feature_counts.items(), key=lambda x: x[1], reverse=True):
            percentage = (count / total_users) * 100
            print(f"{feature:20}: {count:2d}명 ({percentage:5.1f}%)")

        print("=" * 40)
        print(f"총 사용자: {total_users}명")

        return feature_counts

    except Exception as e:
        print(f"오류 발생: {e}")
        return None

# **현재 세션의 결과 직접 분석**
def analyze_current_session_results():
    """
    현재 세션에서 생성된 3명의 결과 분석
    """
    print("🔍 현재 세션 결과 분석 (3명):")
    print("=" * 30)

    # 현재 확인된 결과
    users_data = [
        {'user': 'AFZUK3MTBIBEDQOPAK3OATUOUKLA', 'primary_feature': 'Directors', 'confidence': 0.096},
        {'user': 'AEYE3LSUHQEX6BWG224MKVXX6XZQ', 'primary_feature': 'Directors', 'confidence': 0.113},
        {'user': 'AHU2GG5RF6YAEWUFNLH3QH5RHDNQ', 'primary_feature': 'Numericals', 'confidence': 0.209}
    ]

    # Feature 분포 계산
    feature_counts = {}
    for user in users_data:
        feature = user['primary_feature']
        feature_counts[feature] = feature_counts.get(feature, 0) + 1

    total = len(users_data)

    for feature, count in sorted(feature_counts.items(), key=lambda x: x[1], reverse=True):
        percentage = (count / total) * 100
        print(f"{feature:15}: {count}명 ({percentage:4.1f}%)")

    print("=" * 30)
    print(f"총 사용자: {total}명")

    # 상세 정보
    print(f"\n📊 상세 정보:")
    for user in users_data:
        print(f"  {user['primary_feature']} 중심 사용자 (신뢰도: {user['confidence']:.3f})")

    return feature_counts

# **실행**
print("=== Feature별 사용자 분포 분석 ===\n")

# 1. 저장된 결과가 있으면 분석
saved_result = analyze_user_feature_distribution()

# 2. 현재 세션 결과 분석
current_result = analyze_current_session_results()

# **더 많은 사용자로 확장 시 예상 분포**
print(f"\n🔮 더 많은 사용자로 확장 시 예상 분포:")
print("=" * 40)
print("Directors        : 40-50% (감독 중심)")
print("Cast             : 20-30% (출연진 중심)")
print("Numericals       : 15-25% (런타임/년도/평점 중심)")
print("DescriptionEmbedding: 5-15% (줄거리 중심)")
print("TitleEmbedding   : 3-10% (제목 중심)")
print("Producers        : 2-8% (제작사 중심)")
# Out:
# === Feature별 사용자 분포 분석 ===
#
# ✅ 저장된 파일에서 결과 로드
# 총 1697명의 사용자 분석
#
# 🎯 Feature별 사용자 분포:
# ========================================
# Numericals          : 618명 ( 36.4%)
# Directors           : 617명 ( 36.4%)
# Cast                : 272명 ( 16.0%)
# Producers           : 86명 (  5.1%)
# TitleEmbedding      : 53명 (  3.1%)
# DescriptionEmbedding: 51명 (  3.0%)
# ========================================
# 총 사용자: 1697명
# 🔍 현재 세션 결과 분석 (3명):
# ==============================
# Directors      : 2명 (66.7%)
# Numericals     : 1명 (33.3%)
# ==============================
# 총 사용자: 3명
#
# 📊 상세 정보:
#   Directors 중심 사용자 (신뢰도: 0.096)
#   Directors 중심 사용자 (신뢰도: 0.113)
#   Numericals 중심 사용자 (신뢰도: 0.209)
#
# 🔮 더 많은 사용자로 확장 시 예상 분포:
# ========================================
# Directors        : 40-50% (감독 중심)
# Cast             : 20-30% (출연진 중심)
# Numericals       : 15-25% (런타임/년도/평점 중심)
# DescriptionEmbedding: 5-15% (줄거리 중심)
# TitleEmbedding   : 3-10% (제목 중심)
# Producers        : 2-8% (제작사 중심)

# %%
# **영화별 추천 횟수 분석 함수**

def analyze_movie_recommendation_frequency(df):
    """
    최종 추천 결과에서 영화별 추천 횟수 분석
    """
    print("=== 영화별 추천 횟수 분석 ===\n")

    # 모든 추천 영화 수집
    all_recommended_movies = []
    movie_details = {}  # 영화 상세 정보 저장

    for _, row in df.iterrows():
        user_id = row['user_id']
        recs = row.get('recommendation_candidates', [])

        if isinstance(recs, list):
            for rec in recs:
                if isinstance(rec, dict):
                    # 영화 식별자 추출
                    movie_id = rec.get('asin_mapped', rec.get('asin', 'Unknown'))
                    title = rec.get('title', 'Unknown Title')

                    all_recommended_movies.append(movie_id)

                    # 영화 상세 정보 저장 (중복 방지)
                    if movie_id not in movie_details:
                        movie_details[movie_id] = {
                            'title': title,
                            'directors': rec.get('directors', 'Unknown'),
                            'cast': rec.get('cast', 'Unknown'),
                            'average_rating': rec.get('average_rating', 'Unknown'),
                            'asin': rec.get('asin', 'Unknown')
                        }

    if not all_recommended_movies:
        print("❌ 추천 영화 데이터가 없습니다.")
        return None

    # 영화별 추천 횟수 계산
    recommendation_counts = pd.Series(all_recommended_movies).value_counts()

    print(f"📊 전체 통계:")
    print(f"  총 추천 횟수: {len(all_recommended_movies)}회")
    print(f"  고유 영화 수: {len(recommendation_counts)}개")
    print(f"  평균 추천 횟수: {len(all_recommended_movies) / len(recommendation_counts):.2f}회/영화")

    print(f"\n🎬 영화별 추천 횟수 순위:")
    print("=" * 80)

    for rank, (movie_id, count) in enumerate(recommendation_counts.head(20).items(), 1):
        movie_info = movie_details.get(movie_id, {})
        title = movie_info.get('title', 'Unknown Title')
        directors = movie_info.get('directors', 'Unknown')
        avg_rating = movie_info.get('average_rating', 'Unknown')

        print(f"{rank:2d}. {title}")
        print(f"    추천 횟수: {count}회")
        print(f"    감독: {directors}")
        print(f"    평균 별점: {avg_rating}")
        print(f"    영화 ID: {movie_id}")
        print()

    return recommendation_counts, movie_details

# **추천 다양성 분석 함수**
def analyze_recommendation_diversity(recommendation_counts, total_users):
    """
    추천 다양성 분석
    """
    print("=== 추천 다양성 분석 ===\n")

    unique_movies = len(recommendation_counts)
    total_recommendations = recommendation_counts.sum()

    # 다양성 지표 계산
    diversity_ratio = unique_movies / total_recommendations

    # 집중도 분석 (상위 영화들이 전체 추천에서 차지하는 비율)
    top_5_ratio = recommendation_counts.head(5).sum() / total_recommendations
    top_10_ratio = recommendation_counts.head(10).sum() / total_recommendations

    # 추천 분포 분석
    once_recommended = sum(1 for count in recommendation_counts if count == 1)
    multiple_recommended = sum(1 for count in recommendation_counts if count > 1)

    print(f"📈 다양성 지표:")
    print(f"  다양성 비율: {diversity_ratio:.3f} (높을수록 다양함)")
    print(f"  상위 5개 영화 집중도: {top_5_ratio:.1%}")
    print(f"  상위 10개 영화 집중도: {top_10_ratio:.1%}")

    print(f"\n📊 추천 분포:")
    print(f"  1회만 추천된 영화: {once_recommended}개 ({once_recommended/unique_movies:.1%})")
    print(f"  여러 번 추천된 영화: {multiple_recommended}개 ({multiple_recommended/unique_movies:.1%})")

    # 추천 빈도별 분포
    frequency_distribution = recommendation_counts.value_counts().sort_index()
    print(f"\n🔢 추천 빈도별 분포:")
    for freq, movie_count in frequency_distribution.items():
        print(f"  {freq}회 추천: {movie_count}개 영화")

# **Feature별 인기 영화 분석**
def analyze_popular_movies_by_feature(df):
    """
    각 Feature별로 인기 있는 영화 분석
    """
    print("=== Feature별 인기 영화 분석 ===\n")

    feature_movies = {
        'Directors': [],
        'Producers': [],
        'Cast': [],
        'Numericals': [],
        'DescriptionEmbedding': [],
        'TitleEmbedding': []
    }

    # 사용자의 주요 특성별로 추천 영화 분류
    for _, row in df.iterrows():
        user_profile = row.get('user_profile')
        recs = row.get('recommendation_candidates', [])

        if user_profile and 'primary_feature' in user_profile:
            primary_feature = user_profile['primary_feature']

            for rec in recs:
                if isinstance(rec, dict):
                    movie_title = rec.get('title', 'Unknown')
                    feature_movies[primary_feature].append(movie_title)

    # 각 Feature별 인기 영화 출력
    for feature, movies in feature_movies.items():
        if movies:
            movie_counts = pd.Series(movies).value_counts()
            print(f"🎯 {feature} 중심 사용자들이 선호하는 영화:")
            for title, count in movie_counts.head(5).items():
                print(f"  {title}: {count}회")
            print()

# **메인 분석 함수**
def main_movie_frequency_analysis():
    """
    영화별 추천 횟수 메인 분석
    """
    try:
        # 결과 로드 시도
        result_path = '/content/drive/MyDrive/데사경영학술제/data/final_complete_recommendations.pkl'

        try:
            final_df = pd.read_pickle(result_path)
            print("✅ 저장된 결과 파일 로드 성공")
        except:
            # 현재 세션의 결과 사용
            if 'debug_results' in globals():
                final_df = pd.DataFrame(debug_results)
                print("✅ 현재 세션 결과 사용")
            else:
                print("❌ 분석할 데이터가 없습니다.")
                print("추천 시스템을 먼저 실행해주세요.")
                return

        total_users = len(final_df)
        print(f"분석 대상: {total_users}명의 사용자\n")

        # 1. 영화별 추천 횟수 분석
        recommendation_counts, movie_details = analyze_movie_recommendation_frequency(final_df)

        if recommendation_counts is not None:
            print("\n" + "="*60)

            # 2. 추천 다양성 분석
            analyze_recommendation_diversity(recommendation_counts, total_users)

            print("\n" + "="*60)

            # 3. Feature별 인기 영화 분석
            analyze_popular_movies_by_feature(final_df)

            return recommendation_counts, movie_details

    except Exception as e:
        print(f"❌ 분석 중 오류 발생: {e}")
        return None

# **실행**
print("=== 영화별 추천 횟수 분석 시작 ===\n")
result = main_movie_frequency_analysis()
# Out:
# === 영화별 추천 횟수 분석 시작 ===
#
# ✅ 저장된 결과 파일 로드 성공
# 분석 대상: 1697명의 사용자
#
# === 영화별 추천 횟수 분석 ===
#
# 📊 전체 통계:
#   총 추천 횟수: 8485회
#   고유 영화 수: 110개
#   평균 추천 횟수: 77.14회/영화
#
# 🎬 영화별 추천 횟수 순위:
# ================================================================================
#  1. Sense And Sensibility
#     추천 횟수: 1290회
#     감독: Ang Lee
#     평균 별점: 4.800000190734863
#     영화 ID: 434
#
#  2. Bridge on the River Kwai, The
#     추천 횟수: 913회
#     감독: David Lean
#     평균 별점: 4.800000190734863
#     영화 ID: 1283
#
#  3. Gaslight (1944)
#     추천 횟수: 904회
#     감독: George Cukor
#     평균 별점: 4.699999809265137
#     영화 ID: 1973
#
#  4. Downton Abbey
#     추천 횟수: 828회
#     감독: Brian Percival, Andy Goddard, Jeremy Webb, David Evans
#     평균 별점: 4.900000095367432
#     영화 ID: 412
#
#  5. The Tuskegee Airmen
#     추천 횟수: 657회
#     감독: Robert Markowitz
#     평균 별점: 4.800000190734863
#     영화 ID: 1202
#
#  6. A Christmas Story
#     추천 횟수: 575회
#     감독: Bob Clark
#     평균 별점: 4.800000190734863
#     영화 ID: 296
#
#  7. Gaslight (1944)
#     추천 횟수: 321회
#     감독: George Cukor
#     평균 별점: 4.699999809265137
#     영화 ID: 392
#
#  8. Detective Anna
#     추천 횟수: 313회
#     감독: Feliks Gerchikov, Eugeniy Semenov, Artur Rumynskiy
#     평균 별점: 4.5
#     영화 ID: 1719
#
#  9. Scarecrow and Mrs. King
#     추천 횟수: 298회
#     감독: Harvey S. Laidman, Burt Brinckerhoff, Winrich Kolbe, William Wiard, James Frawley, Sidney Hayers, Sigmund Neufeld Jr., Cliff Bole, Rod Holcomb, Oz Scott
#     평균 별점: 4.800000190734863
#     영화 ID: 1138
#
# 10. The Gathering Storm
#     추천 횟수: 277회
#     감독: Richard Loncraine
#     평균 별점: 4.699999809265137
#     영화 ID: 421
#
# 11. Covert Affairs
#     추천 횟수: 229회
#     감독: Stephen Kay, Félix Enríquez Alcalá, Allan Kroeker, Jamie Barber, Emile B. Levisetti, Kate Woods, J. Miller Tobin, Christopher Gorham, Larysa Kondracki, Ken Girotti
#     평균 별점: 4.699999809265137
#     영화 ID: 609
#
# 12. Captive
#     추천 횟수: 201회
#     감독: Unknown
#     평균 별점: 4.5
#     영화 ID: 962
#
# 13. The Golden Girls
#     추천 횟수: 170회
#     감독: Terry Hughes, Lex Passaris, Matthew Diamond, Jim Drake, Peter D. Beyt, Paul Bogart, Jay Sandrich, Jack Shea, Gary Shimokawa, David Steinberg
#     평균 별점: 4.900000095367432
#     영화 ID: 107
#
# 14. Sense And Sensibility
#     추천 횟수: 112회
#     감독: Ang Lee
#     평균 별점: 4.800000190734863
#     영화 ID: 1884
#
# 15. The Sopranos
#     추천 횟수: 104회
#     감독: Timothy Van Patten, John Patterson, Allen Coulter, Alan Taylor, Henry Bronchtein, Jack Bender, Steve Buscemi, Daniel Attias, David Chase, Nick Gomez
#     평균 별점: 4.900000095367432
#     영화 ID: 317
#
# 16. Red
#     추천 횟수: 96회
#     감독: Robert Schwentke
#     평균 별점: 4.699999809265137
#     영화 ID: 1926
#
# 17. High Society (1956)
#     추천 횟수: 84회
#     감독: Charles Walters
#     평균 별점: 4.800000190734863
#     영화 ID: 1441
#
# 18. The Bourne Identity
#     추천 횟수: 73회
#     감독: Doug Liman
#     평균 별점: 4.800000190734863
#     영화 ID: 1156
#
# 19. Mr. Deeds Goes To Town
#     추천 횟수: 73회
#     감독: Frank Capra
#     평균 별점: 4.800000190734863
#     영화 ID: 1661
#
# 20. Downton Abbey
#     추천 횟수: 70회
#     감독: Brian Percival, David Evans, Philip John, Andy Goddard, Catherine Morshead, Minkie Spiro, Brian Kelly, Michael Engler, Ben Bolt, Ashley Pearce
#     평균 별점: 4.900000095367432
#     영화 ID: 433
#
#
# ============================================================
# === 추천 다양성 분석 ===
#
# 📈 다양성 지표:
#   다양성 비율: 0.013 (높을수록 다양함)
#   상위 5개 영화 집중도: 54.1%
#   상위 10개 영화 집중도: 75.1%
#
# 📊 추천 분포:
#   1회만 추천된 영화: 24개 (21.8%)
#   여러 번 추천된 영화: 86개 (78.2%)
#
# 🔢 추천 빈도별 분포:
#   1회 추천: 24개 영화
#   2회 추천: 13개 영화
#   3회 추천: 7개 영화
#   4회 추천: 3개 영화
#   5회 추천: 4개 영화
#   6회 추천: 4개 영화
#   7회 추천: 3개 영화
#   8회 추천: 1개 영화
#   9회 추천: 2개 영화
#   10회 추천: 1개 영화
#   11회 추천: 1개 영화
#   12회 추천: 1개 영화
#   13회 추천: 2개 영화
#   15회 추천: 2개 영화
#   16회 추천: 4개 영화
#   18회 추천: 1개 영화
#   19회 추천: 1개 영화
#   20회 추천: 1개 영화
#   21회 추천: 1개 영화
#   22회 추천: 1개 영화
#   23회 추천: 1개 영화
#   24회 추천: 1개 영화
#   26회 추천: 2개 영화
#   27회 추천: 1개 영화
#   30회 추천: 1개 영화
#   31회 추천: 1개 영화
#   33회 추천: 1개 영화
#   34회 추천: 1개 영화
#   36회 추천: 1개 영화
#   53회 추천: 1개 영화
#   59회 추천: 1개 영화
#   68회 추천: 1개 영화
#   70회 추천: 1개 영화
#   73회 추천: 2개 영화
#   84회 추천: 1개 영화
#   96회 추천: 1개 영화
#   104회 추천: 1개 영화
#   112회 추천: 1개 영화
#   170회 추천: 1개 영화
#   201회 추천: 1개 영화
#   229회 추천: 1개 영화
#   277회 추천: 1개 영화
#   298회 추천: 1개 영화
#   313회 추천: 1개 영화
#   321회 추천: 1개 영화
#   575회 추천: 1개 영화
#   657회 추천: 1개 영화
#   828회 추천: 1개 영화
#   904회 추천: 1개 영화
#   913회 추천: 1개 영화
#   1290회 추천: 1개 영화
#
# ============================================================
# === Feature별 인기 영화 분석 ===
#
# 🎯 Directors 중심 사용자들이 선호하는 영화:
#   Sense And Sensibility: 658회
#   Gaslight (1944): 606회
#   Downton Abbey: 510회
#   Bridge on the River Kwai, The: 458회
#   The Tuskegee Airmen: 409회
#
# 🎯 Producers 중심 사용자들이 선호하는 영화:
#   Sense And Sensibility: 193회
#   Gaslight (1944): 153회
#   Bridge on the River Kwai, The: 112회
#   Downton Abbey: 86회
#   A Christmas Story: 57회
#
# 🎯 Cast 중심 사용자들이 선호하는 영화:
#   Sense And Sensibility: 53회
#   Gaslight (1944): 48회
#   Bridge on the River Kwai, The: 23회
#   Covert Affairs: 11회
#   Downton Abbey: 11회
#
# 🎯 Numericals 중심 사용자들이 선호하는 영화:
#   Sense And Sensibility: 389회
#   Gaslight (1944): 322회
#   Bridge on the River Kwai, The: 250회
#   Downton Abbey: 218회
#   The Tuskegee Airmen: 156회
#
# 🎯 DescriptionEmbedding 중심 사용자들이 선호하는 영화:
#   Sense And Sensibility: 92회
#   Gaslight (1944): 82회
#   Bridge on the River Kwai, The: 58회
#   Downton Abbey: 55회
#   The Tuskegee Airmen: 35회
#
# 🎯 TitleEmbedding 중심 사용자들이 선호하는 영화:
#   Downton Abbey: 18회
#   Sense And Sensibility: 17회
#   Gaslight (1944): 14회
#   Bridge on the River Kwai, The: 12회
#   The Tuskegee Airmen: 11회
